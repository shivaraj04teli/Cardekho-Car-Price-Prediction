# %%
import json
import ast
import pandas as pd
from typing import Dict, List, Any
from pathlib import Path
import logging

def parse_json_safely(text: str) -> Dict:
    """
    Safely parse JSON string with multiple fallback methods
    """
    if not isinstance(text, str):
        return {}
    
    text = text.strip()
    if not text:
        return {}
        
    try:
        return json.loads(text)
    except json.JSONDecodeError:
        try:
            return ast.literal_eval(text)
        except:
            return {}

def extract_car_details(json_data: Dict) -> Dict[str, Any]:
    """
    Extract information from new_car_detail section
    """
    result = {}
    
    # Direct fields we want to extract
    fields = ['ft', 'bt', 'km', 'transmission', 'ownerNo', 'owner', 
              'oem', 'model', 'modelYear','centralVariantId', 'variantName', 'price', 'priceFixedText', 'trendingText']
    
    for field in fields:
        if field in json_data:
            result[f'detail_{field}'] = json_data[field]
    
    return result

def extract_car_overview(json_data: Dict) -> Dict[str, Any]:
    """
    Extract information from new_car_overview section
    """
    result = {}
    
    if 'top' in json_data and isinstance(json_data['top'], list):
        for item in json_data['top']:
            if isinstance(item, dict) and 'key' in item and 'value' in item:
                key = item['key'].lower().replace(' ', '_').replace('(', '').replace(')', '')
                result[f'overview_{key}'] = item['value']
    
    return result

def extract_car_features(json_data: Dict) -> Dict[str, Any]:
    """
    Extract information from new_car_feature section
    """
    result = {}
    
    # Extract top features
    if 'top' in json_data and isinstance(json_data['top'], list):
        top_features = [item.get('value', '') for item in json_data['top'] if isinstance(item, dict)]
        result['feature_top'] = ', '.join(filter(None, top_features))
    
    # Extract detailed features by category
    if 'data' in json_data and isinstance(json_data['data'], list):
        for category in json_data['data']:
            if isinstance(category, dict) and 'heading' in category and 'list' in category:
                category_name = category['heading'].lower().replace(' & ', '_').replace(' ', '_')
                features = [item.get('value', '') for item in category['list'] if isinstance(item, dict)]
                result[f'feature_{category_name}'] = ', '.join(filter(None, features))
    
    return result

def extract_car_specs(json_data: Dict) -> Dict[str, Any]:
    """
    Extract information from new_car_specs section with proper handling of the nested structure
    """
    result = {}
    
    # Process top-level specifications if present
    if 'top' in json_data and isinstance(json_data['top'], list):
        for item in json_data['top']:
            if isinstance(item, dict) and 'key' in item and 'value' in item:
                clean_key = item['key'].lower().replace(' ', '_').replace('(', '').replace(')', '')
                result[f'specs_top_{clean_key}'] = item['value']
    
    # Process detailed specifications in the data section
    if 'data' in json_data and isinstance(json_data['data'], list):
        for category in json_data['data']:
            if isinstance(category, dict) and 'heading' in category and 'list' in category:
                # Clean the category name
                category_name = category['heading'].lower().replace(' & ', '_').replace(' ', '_')
                
                # Process the specifications list
                if isinstance(category['list'], list):
                    # Store each specification as an individual column
                    for item in category['list']:
                        if isinstance(item, dict) and 'key' in item and 'value' in item:
                            clean_key = item['key'].lower().replace(' ', '_').replace('(', '').replace(')', '')
                            result[f'specs_{category_name}_{clean_key}'] = item['value']
                    
                    # Also store the complete JSON for the category
                    result[f'specs_{category_name}_json'] = json.dumps(category['list'])
    
    return result

def process_excel_files(file_paths: List[str], output_csv: str) -> pd.DataFrame:
    """
    Process Excel files containing car data
    """
    all_data = []
    
    for file_path in file_paths:
        print(f"Processing {file_path}...")
        
        try:
            # Read Excel file
            df = pd.read_excel(file_path)
            
            # Process each row
            for idx, row in df.iterrows():
                processed_row = {
                    'file_name': Path(file_path).name,
                    'row_index': idx
                }
                
                try:
                    # Process specs data using the dedicated function
                    if 'new_car_specs' in row and pd.notna(row['new_car_specs']):
                        specs_data = row['new_car_specs']
                        if isinstance(specs_data, str):
                            try:
                                specs_dict = json.loads(specs_data)
                            except json.JSONDecodeError:
                                try:
                                    specs_dict = ast.literal_eval(specs_data)
                                except:
                                    print(f"Error parsing new_car_specs in row {idx}")
                                    specs_dict = {}
                        else:
                            specs_dict = specs_data
                            
                        if specs_dict:
                            specs_result = extract_car_specs(specs_dict)
                            processed_row.update(specs_result)
                    
                    # Process other JSON columns normally
                    if 'new_car_detail' in row:
                        json_data = parse_json_safely(row['new_car_detail'])
                        processed_row.update(extract_car_details(json_data))
                    
                    if 'new_car_overview' in row:
                        json_data = parse_json_safely(row['new_car_overview'])
                        processed_row.update(extract_car_overview(json_data))
                    
                    if 'new_car_feature' in row:
                        json_data = parse_json_safely(row['new_car_feature'])
                        processed_row.update(extract_car_features(json_data))
                    
                    # Add any non-JSON columns
                    for col in df.columns:
                        if col not in ['new_car_detail', 'new_car_overview', 'new_car_feature', 'new_car_specs']:
                            processed_row[col] = row[col]
                    
                except Exception as e:
                    print(f"Error processing row {idx}: {str(e)}")
                    continue
                
                all_data.append(processed_row)
                
        except Exception as e:
            print(f"Error processing file {file_path}: {str(e)}")
            continue
    
    # Create final DataFrame
    final_df = pd.DataFrame(all_data)
    
    # Save to CSV
    if output_csv:
        final_df.to_csv(output_csv, index=False)
        print(f"Saved processed data to {output_csv}")
        
        # Print column summary
        print("\nExtracted Columns:")
        categories = ['detail_', 'overview_', 'feature_', 'specs_']
        for prefix in categories:
            cols = [col for col in final_df.columns if col.startswith(prefix)]
            if cols:
                print(f"\n{prefix.upper()} columns:")
                for col in sorted(cols):
                    non_null_count = final_df[col].notna().sum()
                    print(f"- {col} ({non_null_count} non-null values)")
        
        print(f"\nTotal number of columns: {len(final_df.columns)}")
        print(f"Total number of rows: {len(final_df)}")
    
    return final_df

def main():
    """
    Main function to execute the processing
    """
    excel_files = [
        r"C:\Users\Shiva\OneDrive\Desktop\cardekho\Dataset-20241106T053909Z-001\Dataset\bangalore_cars.xlsx"
    ]
    output_path = "processed_car_data_v5.csv"
    
    try:
        # Process files
        result_df = process_excel_files(excel_files, output_path)
        
        # Display sample of processed data
        print("\nSample of processed data:")
        print(result_df.head())
        
        # Display some basic statistics
        print("\nBasic Statistics:")
        print(f"Total cars processed: {len(result_df)}")
        if 'detail_price' in result_df.columns:
            print("\nPrice Distribution:")
            print(result_df['detail_price'].value_counts().head())
        
        if 'detail_modelYear' in result_df.columns:
            print("\nModel Year Distribution:")
            print(result_df['detail_modelYear'].value_counts().sort_index().head())
            
    except Exception as e:
        print(f"Error in main execution: {str(e)}")

if __name__ == "__main__":
    main()
# Out:
# Processing C:\Users\Shiva\OneDrive\Desktop\cardekho\Dataset-20241106T053909Z-001\Dataset\bangalore_cars.xlsx...
# Saved processed data to processed_car_data_v5.csv
#
# Extracted Columns:
#
# DETAIL_ columns:
# - detail_bt (1481 non-null values)
# - detail_centralVariantId (1481 non-null values)
# - detail_ft (1481 non-null values)
# - detail_km (1481 non-null values)
# - detail_model (1481 non-null values)
# - detail_modelYear (1481 non-null values)
# - detail_oem (1481 non-null values)
# - detail_owner (1481 non-null values)
# - detail_ownerNo (1481 non-null values)
# - detail_price (1481 non-null values)
# - detail_priceFixedText (0 non-null values)
# - detail_transmission (1481 non-null values)
# - detail_trendingText (1481 non-null values)
# - detail_variantName (1481 non-null values)
#
# OVERVIEW_ columns:
# - overview_engine_displacement (1478 non-null values)
# - overview_fuel_type (1481 non-null values)
# - overview_insurance_validity (1478 non-null values)
# - overview_kms_driven (1481 non-null values)
# - overview_ownership (1481 non-null values)
# - overview_registration_year (1474 non-null values)
# - overview_rto (1313 non-null values)
# - overview_seats (1480 non-null values)
# - overview_transmission (1481 non-null values)
# - overview_year_of_manufacture (1474 non-null values)
#
# FEATURE_ columns:
# - feature_comfort_convenience (1467 non-null values)
# - feature_entertainment_communication (1345 non-null values)
# - feature_exterior (1460 non-null values)
# - feature_interior (1464 non-null values)
# - feature_safety (1459 non-null values)
# - feature_top (1481 non-null values)
#
# SPECS_ columns:
# - specs_dimensions_capacity_front_tread (882 non-null values)
# - specs_dimensions_capacity_gross_weight (688 non-null values)
# - specs_dimensions_capacity_ground_clearance_unladen (87 non-null values)
# - specs_dimensions_capacity_height (1460 non-null values)
# - specs_dimensions_capacity_json (1469 non-null values)
# - specs_dimensions_capacity_kerb_weight (1467 non-null values)
# - specs_dimensions_capacity_length (1460 non-null values)
# - specs_dimensions_capacity_rear_tread (879 non-null values)
# - specs_dimensions_capacity_wheel_base (1446 non-null values)
# - specs_dimensions_capacity_width (1460 non-null values)
# - specs_engine_and_transmission_borex_stroke (383 non-null values)
# - specs_engine_and_transmission_color (1479 non-null values)
# - specs_engine_and_transmission_compression_ratio (317 non-null values)
# - specs_engine_and_transmission_displacement (1478 non-null values)
# - specs_engine_and_transmission_engine_type (1423 non-null values)
# - specs_engine_and_transmission_fuel_suppy_system (1184 non-null values)
# - specs_engine_and_transmission_json (1479 non-null values)
# - specs_engine_and_transmission_max_power (1465 non-null values)
# - specs_engine_and_transmission_max_torque (1465 non-null values)
# - specs_engine_and_transmission_no_of_cylinder (1475 non-null values)
# - specs_engine_and_transmission_super_charger (1142 non-null values)
# - specs_engine_and_transmission_turbo_charger (1288 non-null values)
# - specs_engine_and_transmission_value_configuration (1091 non-null values)
# - specs_engine_and_transmission_values_per_cylinder (1470 non-null values)
# - specs_miscellaneous_acceleration (848 non-null values)
# - specs_miscellaneous_alloy_wheel_size (1029 non-null values)
# - specs_miscellaneous_cargo_volumn (1198 non-null values)
# - specs_miscellaneous_drive_type (1182 non-null values)
# - specs_miscellaneous_front_brake_type (1460 non-null values)
# - specs_miscellaneous_gear_box (1457 non-null values)
# - specs_miscellaneous_json (1480 non-null values)
# - specs_miscellaneous_no_door_numbers (1479 non-null values)
# - specs_miscellaneous_rear_brake_type (1460 non-null values)
# - specs_miscellaneous_seating_capacity (1480 non-null values)
# - specs_miscellaneous_steering_type (1448 non-null values)
# - specs_miscellaneous_top_speed (809 non-null values)
# - specs_miscellaneous_turning_radius (1198 non-null values)
# - specs_miscellaneous_tyre_type (1471 non-null values)
# - specs_top_engine (1478 non-null values)
# - specs_top_max_power (1465 non-null values)
# - specs_top_mileage (1439 non-null values)
# - specs_top_seats (1480 non-null values)
# - specs_top_torque (1465 non-null values)
# - specs_top_wheel_size (1029 non-null values)
#
# Total number of columns: 77
# Total number of rows: 1481
#
# Sample of processed data:
#              file_name  row_index specs_top_mileage specs_top_engine  \
# 0  bangalore_cars.xlsx          0         23.1 kmpl           998 CC
# 1  bangalore_cars.xlsx          1           17 kmpl          1497 CC
# 2  bangalore_cars.xlsx          2        23.84 kmpl          1199 CC
# 3  bangalore_cars.xlsx          3         19.1 kmpl          1197 CC
# 4  bangalore_cars.xlsx          4        23.65 kmpl          1248 CC
#
#   specs_top_max_power specs_top_torque specs_top_seats  \
# 0            67.04bhp             90Nm               5
# 1           121.31bhp            150Nm               5
# 2               84bhp            114Nm               5
# 3            81.86bhp         113.75Nm               5
# 4             88.5bhp            200Nm               5
#
#   specs_engine_and_transmission_color  \
# 0                               White
# 1                               White
# 2                                 Red
# 3                              Others
# 4                                Gray
#
#   specs_engine_and_transmission_engine_type  \
# 0                               K10B Engine
# 1                      Ti-VCT Petrol Engine
# 2                           Revotron Engine
# 3                  Kappa VTVT Petrol Engine
# 4                    DDiS 200 Diesel Engine
#
#   specs_engine_and_transmission_displacement  ...  \
# 0                                        998  ...
# 1                                       1497  ...
# 2                                       1199  ...
# 3                                       1197  ...
# 4                                       1248  ...
#
#                                          feature_top  \
# 0  Power Steering, Power Windows Front, Air Condi...
# 1  Power Steering, Power Windows Front, Air Condi...
# 2  Power Steering, Power Windows Front, Air Condi...
# 3  Power Steering, Power Windows Front, Air Condi...
# 4  Power Steering, Power Windows Front, Air Condi...
#
#                          feature_comfort_convenience  \
# 0  Power Steering, Power Windows Front, Power Win...
# 1  Power Steering, Power Windows Front, Power Win...
# 2  Power Steering, Power Windows Front, Power Win...
# 3  Power Steering, Power Windows Front, Power Win...
# 4  Power Steering, Power Windows Front, Power Win...
#
#                                     feature_interior  \
# 0  Air Conditioner, Heater, Digital Odometer, Ele...
# 1  Air Conditioner, Heater, Adjustable Steering, ...
# 2  Air Conditioner, Heater, Adjustable Steering, ...
# 3  Air Conditioner, Heater, Adjustable Steering, ...
# 4  Air Conditioner, Heater, Adjustable Steering, ...
#
#                                     feature_exterior  \
# 0  Adjustable Head Lights, Manually Adjustable Ex...
# 1  Adjustable Head Lights, Fog Lights Front, Powe...
# 2  Adjustable Head Lights, Fog Lights Front, Powe...
# 3  Adjustable Head Lights, Fog Lights Front, Powe...
# 4  Adjustable Head Lights, Fog Lights Front, Powe...
#
#                                       feature_safety  \
# 0  Centeral Locking, Child Safety Locks, Day Nigh...
# 1  Anti Lock Braking System, Centeral Locking, Po...
# 2  Anti Lock Braking System, Centeral Locking, Po...
# 3  Anti Lock Braking System, Centeral Locking, Po...
# 4  Anti Lock Braking System, Centeral Locking, Po...
#
#                                            car_links specs_top_wheel_size  \
# 0  https://www.cardekho.com/used-car-details/used...                  NaN
# 1  https://www.cardekho.com/buy-used-car-details/...                   16
# 2  https://www.cardekho.com/used-car-details/used...                   14
# 3  https://www.cardekho.com/buy-used-car-details/...                   14
# 4  https://www.cardekho.com/used-car-details/used...                   16
#
#   specs_miscellaneous_alloy_wheel_size  \
# 0                                  NaN
# 1                                   16
# 2                                   14
# 3                                   14
# 4                                   16
#
#                  feature_entertainment_communication  \
# 0                                                NaN
# 1  Cd Player, Radio, Speakers Front, Speakers Rea...
# 2  Cd Player, Radio, Speakers Front, Speakers Rea...
# 3  Cd Player, Radio, Speakers Front, Speakers Rea...
# 4  Radio, Audio System Remote Control, Speakers F...
#
#   specs_dimensions_capacity_ground_clearance_unladen
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 77 columns]
#
# Basic Statistics:
# Total cars processed: 1481
#
# Price Distribution:
# detail_price
# ₹ 6.50 Lakh    20
# ₹ 5 Lakh       16
# ₹ 5.50 Lakh    16
# ₹ 6 Lakh       14
# ₹ 3 Lakh       14
# Name: count, dtype: int64
#
# Model Year Distribution:
# detail_modelYear
# 1995    2
# 1998    2
# 2000    1
# 2001    2
# 2002    1
# Name: count, dtype: int64

# %%
import json
import ast
import pandas as pd
from typing import Dict, List, Any
from pathlib import Path
import logging

# %%
df_4= pd.read_csv("processed_car_data_v5.csv")
df_4.head()
# Out:
#              file_name  row_index specs_top_mileage specs_top_engine  \
# 0  bangalore_cars.xlsx          0         23.1 kmpl           998 CC
# 1  bangalore_cars.xlsx          1           17 kmpl          1497 CC
# 2  bangalore_cars.xlsx          2        23.84 kmpl          1199 CC
# 3  bangalore_cars.xlsx          3         19.1 kmpl          1197 CC
# 4  bangalore_cars.xlsx          4        23.65 kmpl          1248 CC
#
#   specs_top_max_power specs_top_torque  specs_top_seats  \
# 0            67.04bhp             90Nm              5.0
# 1           121.31bhp            150Nm              5.0
# 2               84bhp            114Nm              5.0
# 3            81.86bhp         113.75Nm              5.0
# 4             88.5bhp            200Nm              5.0
#
#   specs_engine_and_transmission_color  \
# 0                               White
# 1                               White
# 2                                 Red
# 3                              Others
# 4                                Gray
#
#   specs_engine_and_transmission_engine_type  \
# 0                               K10B Engine
# 1                      Ti-VCT Petrol Engine
# 2                           Revotron Engine
# 3                  Kappa VTVT Petrol Engine
# 4                    DDiS 200 Diesel Engine
#
#    specs_engine_and_transmission_displacement  ...  \
# 0                                       998.0  ...
# 1                                      1497.0  ...
# 2                                      1199.0  ...
# 3                                      1197.0  ...
# 4                                      1248.0  ...
#
#                                          feature_top  \
# 0  Power Steering, Power Windows Front, Air Condi...
# 1  Power Steering, Power Windows Front, Air Condi...
# 2  Power Steering, Power Windows Front, Air Condi...
# 3  Power Steering, Power Windows Front, Air Condi...
# 4  Power Steering, Power Windows Front, Air Condi...
#
#                          feature_comfort_convenience  \
# 0  Power Steering, Power Windows Front, Power Win...
# 1  Power Steering, Power Windows Front, Power Win...
# 2  Power Steering, Power Windows Front, Power Win...
# 3  Power Steering, Power Windows Front, Power Win...
# 4  Power Steering, Power Windows Front, Power Win...
#
#                                     feature_interior  \
# 0  Air Conditioner, Heater, Digital Odometer, Ele...
# 1  Air Conditioner, Heater, Adjustable Steering, ...
# 2  Air Conditioner, Heater, Adjustable Steering, ...
# 3  Air Conditioner, Heater, Adjustable Steering, ...
# 4  Air Conditioner, Heater, Adjustable Steering, ...
#
#                                     feature_exterior  \
# 0  Adjustable Head Lights, Manually Adjustable Ex...
# 1  Adjustable Head Lights, Fog Lights Front, Powe...
# 2  Adjustable Head Lights, Fog Lights Front, Powe...
# 3  Adjustable Head Lights, Fog Lights Front, Powe...
# 4  Adjustable Head Lights, Fog Lights Front, Powe...
#
#                                       feature_safety  \
# 0  Centeral Locking, Child Safety Locks, Day Nigh...
# 1  Anti Lock Braking System, Centeral Locking, Po...
# 2  Anti Lock Braking System, Centeral Locking, Po...
# 3  Anti Lock Braking System, Centeral Locking, Po...
# 4  Anti Lock Braking System, Centeral Locking, Po...
#
#                                            car_links specs_top_wheel_size  \
# 0  https://www.cardekho.com/used-car-details/used...                  NaN
# 1  https://www.cardekho.com/buy-used-car-details/...                   16
# 2  https://www.cardekho.com/used-car-details/used...                   14
# 3  https://www.cardekho.com/buy-used-car-details/...                   14
# 4  https://www.cardekho.com/used-car-details/used...                   16
#
#   specs_miscellaneous_alloy_wheel_size  \
# 0                                  NaN
# 1                                   16
# 2                                   14
# 3                                   14
# 4                                   16
#
#                  feature_entertainment_communication  \
# 0                                                NaN
# 1  Cd Player, Radio, Speakers Front, Speakers Rea...
# 2  Cd Player, Radio, Speakers Front, Speakers Rea...
# 3  Cd Player, Radio, Speakers Front, Speakers Rea...
# 4  Radio, Audio System Remote Control, Speakers F...
#
#   specs_dimensions_capacity_ground_clearance_unladen
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 77 columns]

# %%
# Specify the full path with the filename, not just the directory
output_path = r"C:\Users\Shiva\OneDrive\Desktop\cardekho\Dataset-20241106T053909Z-001\Dataset\processed_data.csv"

# Save the DataFrame to the specified path
df_4.to_csv(output_path, index=False)

print(f"CSV file has been exported to '{output_path}'")
# Out:
# CSV file has been exported to 'C:\Users\Shiva\OneDrive\Desktop\cardekho\Dataset-20241106T053909Z-001\Dataset\processed_data.csv'

# %%
import json
import ast
import pandas as pd
from typing import Dict, List, Any
from pathlib import Path
import logging

def parse_json_safely(text: str) -> Dict:
    """
    Safely parse JSON string with multiple fallback methods
    """
    if not isinstance(text, str):
        return {}
    
    text = text.strip()
    if not text:
        return {}
        
    try:
        return json.loads(text)
    except json.JSONDecodeError:
        try:
            return ast.literal_eval(text)
        except:
            return {}

def extract_car_details(json_data: Dict) -> Dict[str, Any]:
    """
    Extract information from new_car_detail section
    """
    result = {}
    
    # Direct fields we want to extract
    fields = ['ft', 'bt', 'km', 'transmission', 'ownerNo', 'owner', 
              'oem', 'model', 'modelYear','centralVariantId', 'variantName', 'price', 'priceFixedText', 'trendingText']
    
    for field in fields:
        if field in json_data:
            result[f'detail_{field}'] = json_data[field]
    
    return result

def extract_car_overview(json_data: Dict) -> Dict[str, Any]:
    """
    Extract information from new_car_overview section
    """
    result = {}
    
    if 'top' in json_data and isinstance(json_data['top'], list):
        for item in json_data['top']:
            if isinstance(item, dict) and 'key' in item and 'value' in item:
                key = item['key'].lower().replace(' ', '_').replace('(', '').replace(')', '')
                result[f'overview_{key}'] = item['value']
    
    return result

def extract_car_features(json_data: Dict) -> Dict[str, Any]:
    """
    Extract information from new_car_feature section
    """
    result = {}
    
    # Extract top features
    if 'top' in json_data and isinstance(json_data['top'], list):
        top_features = [item.get('value', '') for item in json_data['top'] if isinstance(item, dict)]
        result['feature_top'] = ', '.join(filter(None, top_features))
    
    # Extract detailed features by category
    if 'data' in json_data and isinstance(json_data['data'], list):
        for category in json_data['data']:
            if isinstance(category, dict) and 'heading' in category and 'list' in category:
                category_name = category['heading'].lower().replace(' & ', '_').replace(' ', '_')
                features = [item.get('value', '') for item in category['list'] if isinstance(item, dict)]
                result[f'feature_{category_name}'] = ', '.join(filter(None, features))
    
    return result

def extract_car_specs(json_data: Dict) -> Dict[str, Any]:
    """
    Extract information from new_car_specs section with proper handling of the nested structure
    """
    result = {}
    
    # Process top-level specifications if present
    if 'top' in json_data and isinstance(json_data['top'], list):
        for item in json_data['top']:
            if isinstance(item, dict) and 'key' in item and 'value' in item:
                clean_key = item['key'].lower().replace(' ', '_').replace('(', '').replace(')', '')
                result[f'specs_top_{clean_key}'] = item['value']
    
    # Process detailed specifications in the data section
    if 'data' in json_data and isinstance(json_data['data'], list):
        for category in json_data['data']:
            if isinstance(category, dict) and 'heading' in category and 'list' in category:
                # Clean the category name
                category_name = category['heading'].lower().replace(' & ', '_').replace(' ', '_')
                
                # Process the specifications list
                if isinstance(category['list'], list):
                    # Store each specification as an individual column
                    for item in category['list']:
                        if isinstance(item, dict) and 'key' in item and 'value' in item:
                            clean_key = item['key'].lower().replace(' ', '_').replace('(', '').replace(')', '')
                            result[f'specs_{category_name}_{clean_key}'] = item['value']
                    
                    # Also store the complete JSON for the category
                    result[f'specs_{category_name}_json'] = json.dumps(category['list'])
    
    return result

def process_excel_files(file_paths: List[str], output_csv: str) -> pd.DataFrame:
    """
    Process Excel files containing car data with location verification
    """
    all_data = []
    
    for file_path in file_paths:
        print(f"\nProcessing {file_path}...")
        
        try:
            # Read Excel file
            df = pd.read_excel(file_path)
            
            # Print initial data info
            print(f"Initial data shape: {df.shape}")
            
            # Check if 'city' column exists and print unique cities
            if 'city' in df.columns:
                print("Cities in dataset:", df['city'].unique())
            elif 'location' in df.columns:
                print("Locations in dataset:", df['location'].unique())
            
            # Process each row
            for idx, row in df.iterrows():
                processed_row = {
                    'file_name': Path(file_path).name,
                    'row_index': idx
                }
                
                try:
                    # Store location information if available
                    if 'city' in row:
                        processed_row['city'] = row['city']
                    if 'location' in row:
                        processed_row['location'] = row['location']
                    
                    # Process specs data using the dedicated function
                    if 'new_car_specs' in row and pd.notna(row['new_car_specs']):
                        specs_data = row['new_car_specs']
                        if isinstance(specs_data, str):
                            try:
                                specs_dict = json.loads(specs_data)
                            except json.JSONDecodeError:
                                try:
                                    specs_dict = ast.literal_eval(specs_data)
                                except:
                                    print(f"Error parsing new_car_specs in row {idx}")
                                    specs_dict = {}
                        else:
                            specs_dict = specs_data
                            
                        if specs_dict:
                            specs_result = extract_car_specs(specs_dict)
                            processed_row.update(specs_result)
                    
                    # Process car details and extract location if present
                    if 'new_car_detail' in row:
                        json_data = parse_json_safely(row['new_car_detail'])
                        detail_result = extract_car_details(json_data)
                        processed_row.update(detail_result)
                        
                        # Check if location info is in car details
                        if 'city' in json_data:
                            processed_row['detail_city'] = json_data['city']
                        if 'location' in json_data:
                            processed_row['detail_location'] = json_data['location']
                    
                    if 'new_car_overview' in row:
                        json_data = parse_json_safely(row['new_car_overview'])
                        processed_row.update(extract_car_overview(json_data))
                    
                    if 'new_car_feature' in row:
                        json_data = parse_json_safely(row['new_car_feature'])
                        processed_row.update(extract_car_features(json_data))
                    
                    # Add any non-JSON columns
                    for col in df.columns:
                        if col not in ['new_car_detail', 'new_car_overview', 'new_car_feature', 'new_car_specs']:
                            processed_row[col] = row[col]
                    
                except Exception as e:
                    print(f"Error processing row {idx}: {str(e)}")
                    continue
                
                all_data.append(processed_row)
                
        except Exception as e:
            print(f"Error processing file {file_path}: {str(e)}")
            continue
    
    # Create final DataFrame
    final_df = pd.DataFrame(all_data)
    
    # Verify location data
    print("\nLocation verification:")
    location_columns = ['city', 'location', 'detail_city', 'detail_location']
    for col in location_columns:
        if col in final_df.columns:
            print(f"\nUnique values in {col}:")
            print(final_df[col].value_counts().head())
    
    # Save to CSV
    if output_csv:
        final_df.to_csv(output_csv, index=False)
        print(f"\nSaved processed data to {output_csv}")
        
        # Print column summary
        print("\nExtracted Columns:")
        categories = ['detail_', 'overview_', 'feature_', 'specs_']
        for prefix in categories:
            cols = [col for col in final_df.columns if col.startswith(prefix)]
            if cols:
                print(f"\n{prefix.upper()} columns:")
                for col in sorted(cols):
                    non_null_count = final_df[col].notna().sum()
                    print(f"- {col} ({non_null_count} non-null values)")
        
        print(f"\nTotal number of columns: {len(final_df.columns)}")
        print(f"Total number of rows: {len(final_df)}")
    
    return final_df

def main():
    """
    Main function to execute the processing with additional verification
    """
    excel_files = [
        r"C:\Users\Shiva\OneDrive\Desktop\cardekho\Dataset-20241106T053909Z-001\Dataset\chennai_cars.xlsx"
    ]
    output_path = "processed_car_data_chennai.csv"
    
    try:
        # Process files
        result_df = process_excel_files(excel_files, output_path)
        
        # Verify location data
        print("\nFinal Location Verification:")
        location_cols = ['city', 'location', 'detail_city', 'detail_location']
        for col in location_cols:
            if col in result_df.columns:
                print(f"\nDistribution of {col}:")
                print(result_df[col].value_counts().head())
        
        # Display sample of processed data
        print("\nSample of processed data:")
        print(result_df.head())
        
        # Display some basic statistics
        print("\nBasic Statistics:")
        print(f"Total cars processed: {len(result_df)}")
        if 'detail_price' in result_df.columns:
            print("\nPrice Distribution:")
            print(result_df['detail_price'].value_counts().head())
        
        if 'detail_modelYear' in result_df.columns:
            print("\nModel Year Distribution:")
            print(result_df['detail_modelYear'].value_counts().sort_index().head())
            
    except Exception as e:
        print(f"Error in main execution: {str(e)}")

if __name__ == "__main__":
    main()
# Out:
# Processing C:\Users\Shiva\OneDrive\Desktop\cardekho\Dataset-20241106T053909Z-001\Dataset\chennai_cars.xlsx...
# Initial data shape: (1419, 5)
#
# Location verification:
#
# Saved processed data to processed_car_data_chennai.csv
#
# Extracted Columns:
#
# DETAIL_ columns:
# - detail_bt (1419 non-null values)
# - detail_centralVariantId (1419 non-null values)
# - detail_ft (1419 non-null values)
# - detail_km (1419 non-null values)
# - detail_model (1419 non-null values)
# - detail_modelYear (1419 non-null values)
# - detail_oem (1419 non-null values)
# - detail_owner (1419 non-null values)
# - detail_ownerNo (1419 non-null values)
# - detail_price (1419 non-null values)
# - detail_priceFixedText (0 non-null values)
# - detail_transmission (1419 non-null values)
# - detail_trendingText (1419 non-null values)
# - detail_variantName (1419 non-null values)
#
# OVERVIEW_ columns:
# - overview_engine_displacement (1419 non-null values)
# - overview_fuel_type (1419 non-null values)
# - overview_insurance_validity (1419 non-null values)
# - overview_kms_driven (1419 non-null values)
# - overview_ownership (1397 non-null values)
# - overview_registration_year (1397 non-null values)
# - overview_rto (1309 non-null values)
# - overview_seats (1419 non-null values)
# - overview_transmission (1419 non-null values)
# - overview_year_of_manufacture (1419 non-null values)
#
# FEATURE_ columns:
# - feature_comfort_convenience (1402 non-null values)
# - feature_entertainment_communication (1266 non-null values)
# - feature_exterior (1398 non-null values)
# - feature_interior (1401 non-null values)
# - feature_safety (1398 non-null values)
# - feature_top (1419 non-null values)
#
# SPECS_ columns:
# - specs_dimensions_capacity_front_tread (810 non-null values)
# - specs_dimensions_capacity_gross_weight (602 non-null values)
# - specs_dimensions_capacity_ground_clearance_unladen (102 non-null values)
# - specs_dimensions_capacity_height (1405 non-null values)
# - specs_dimensions_capacity_json (1413 non-null values)
# - specs_dimensions_capacity_kerb_weight (1407 non-null values)
# - specs_dimensions_capacity_length (1405 non-null values)
# - specs_dimensions_capacity_rear_tread (804 non-null values)
# - specs_dimensions_capacity_wheel_base (1388 non-null values)
# - specs_dimensions_capacity_width (1404 non-null values)
# - specs_engine_and_transmission_borex_stroke (423 non-null values)
# - specs_engine_and_transmission_color (1419 non-null values)
# - specs_engine_and_transmission_compression_ratio (326 non-null values)
# - specs_engine_and_transmission_displacement (1419 non-null values)
# - specs_engine_and_transmission_engine_type (1371 non-null values)
# - specs_engine_and_transmission_fuel_suppy_system (1148 non-null values)
# - specs_engine_and_transmission_json (1419 non-null values)
# - specs_engine_and_transmission_max_power (1408 non-null values)
# - specs_engine_and_transmission_max_torque (1408 non-null values)
# - specs_engine_and_transmission_no_of_cylinder (1418 non-null values)
# - specs_engine_and_transmission_super_charger (1109 non-null values)
# - specs_engine_and_transmission_turbo_charger (1275 non-null values)
# - specs_engine_and_transmission_value_configuration (1083 non-null values)
# - specs_engine_and_transmission_values_per_cylinder (1413 non-null values)
# - specs_miscellaneous_acceleration (866 non-null values)
# - specs_miscellaneous_alloy_wheel_size (951 non-null values)
# - specs_miscellaneous_cargo_volumn (1204 non-null values)
# - specs_miscellaneous_drive_type (1183 non-null values)
# - specs_miscellaneous_front_brake_type (1400 non-null values)
# - specs_miscellaneous_gear_box (1400 non-null values)
# - specs_miscellaneous_json (1419 non-null values)
# - specs_miscellaneous_no_door_numbers (1419 non-null values)
# - specs_miscellaneous_rear_brake_type (1400 non-null values)
# - specs_miscellaneous_seating_capacity (1419 non-null values)
# - specs_miscellaneous_steering_type (1390 non-null values)
# - specs_miscellaneous_top_speed (819 non-null values)
# - specs_miscellaneous_turning_radius (1136 non-null values)
# - specs_miscellaneous_tyre_type (1407 non-null values)
# - specs_top_engine (1419 non-null values)
# - specs_top_max_power (1408 non-null values)
# - specs_top_mileage (1375 non-null values)
# - specs_top_seats (1419 non-null values)
# - specs_top_torque (1408 non-null values)
# - specs_top_wheel_size (951 non-null values)
#
# Total number of columns: 77
# Total number of rows: 1419
#
# Final Location Verification:
#
# Sample of processed data:
#            file_name  row_index specs_top_engine specs_top_max_power  \
# 0  chennai_cars.xlsx          0           998 CC           118.36bhp
# 1  chennai_cars.xlsx          1          1196 CC               73bhp
# 2  chennai_cars.xlsx          2           999 CC            98.63bhp
# 3  chennai_cars.xlsx          3          1086 CC            68.05bhp
# 4  chennai_cars.xlsx          4          1199 CC             88.7bhp
#
#   specs_top_torque specs_top_wheel_size specs_top_seats  \
# 0            172nm                   16               5
# 1            101Nm                  NaN               7
# 2            160Nm                   16               5
# 3          99.04Nm                  NaN               5
# 4            110Nm                   15               5
#
#   specs_engine_and_transmission_color  \
# 0                               Black
# 1                                Grey
# 2                              Others
# 3                              Silver
# 4                              Others
#
#   specs_engine_and_transmission_engine_type  \
# 0                  Smartstream G1.0 T - GDi
# 1                            In-Line Engine
# 2                     HRA0 1.0 TURBO PETROL
# 3                              IRDE2 Engine
# 4                      i-VTEC Petrol Engine
#
#   specs_engine_and_transmission_displacement  ...  \
# 0                                        998  ...
# 1                                       1196  ...
# 2                                        999  ...
# 3                                       1086  ...
# 4                                       1199  ...
#
#   specs_engine_and_transmission_compression_ratio  \
# 0                                             NaN
# 1                                           9.9:1
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
#   specs_engine_and_transmission_super_charger  \
# 0                                         NaN
# 1                                          No
# 2                                          No
# 3                                          No
# 4                                          No
#
#    specs_dimensions_capacity_front_tread  \
# 0                                    NaN
# 1                                 1280mm
# 2                                    NaN
# 3                                 1400mm
# 4                                    NaN
#
#    specs_dimensions_capacity_rear_tread  \
# 0                                   NaN
# 1                                1290mm
# 2                                   NaN
# 3                                1385mm
# 4                                   NaN
#
#   specs_dimensions_capacity_gross_weight specs_miscellaneous_turning_radius  \
# 0                                    NaN                                NaN
# 1                                 1540kg                         4.5 metres
# 2                                    NaN                                5.0
# 3                                    NaN                         4.7 metres
# 4                                    NaN                         5.1 meters
#
#   specs_miscellaneous_top_speed specs_miscellaneous_acceleration  \
# 0                           NaN                              NaN
# 1                      145 Kmph                     15.7 Seconds
# 2                           NaN                             11.7
# 3                      165 Kmph                     14.3 Seconds
# 4                      172 Kmph                     13.7 Seconds
#
#   specs_engine_and_transmission_borex_stroke  \
# 0                                        NaN
# 1                                        NaN
# 2                                72.2 x 81.3
# 3                                        NaN
# 4                                        NaN
#
#   specs_dimensions_capacity_ground_clearance_unladen
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 77 columns]
#
# Basic Statistics:
# Total cars processed: 1419
#
# Price Distribution:
# detail_price
# ₹ 6.50 Lakh    20
# ₹ 7.50 Lakh    17
# ₹ 5 Lakh       15
# ₹ 9.50 Lakh    14
# ₹ 4.50 Lakh    14
# Name: count, dtype: int64
#
# Model Year Distribution:
# detail_modelYear
# 2002    4
# 2003    2
# 2004    2
# 2005    4
# 2006    2
# Name: count, dtype: int64

# %%
df_chennai= pd.read_csv("processed_car_data_chennai.csv")
df_chennai.head()
# Out:
#            file_name  row_index specs_top_engine specs_top_max_power  \
# 0  chennai_cars.xlsx          0           998 CC           118.36bhp
# 1  chennai_cars.xlsx          1          1196 CC               73bhp
# 2  chennai_cars.xlsx          2           999 CC            98.63bhp
# 3  chennai_cars.xlsx          3          1086 CC            68.05bhp
# 4  chennai_cars.xlsx          4          1199 CC             88.7bhp
#
#   specs_top_torque specs_top_wheel_size  specs_top_seats  \
# 0            172nm                   16                5
# 1            101Nm                  NaN                7
# 2            160Nm                   16                5
# 3          99.04Nm                  NaN                5
# 4            110Nm                   15                5
#
#   specs_engine_and_transmission_color  \
# 0                               Black
# 1                                Grey
# 2                              Others
# 3                              Silver
# 4                              Others
#
#   specs_engine_and_transmission_engine_type  \
# 0                  Smartstream G1.0 T - GDi
# 1                            In-Line Engine
# 2                     HRA0 1.0 TURBO PETROL
# 3                              IRDE2 Engine
# 4                      i-VTEC Petrol Engine
#
#    specs_engine_and_transmission_displacement  ...  \
# 0                                         998  ...
# 1                                        1196  ...
# 2                                         999  ...
# 3                                        1086  ...
# 4                                        1199  ...
#
#   specs_engine_and_transmission_compression_ratio  \
# 0                                             NaN
# 1                                           9.9:1
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
#   specs_engine_and_transmission_super_charger  \
# 0                                         NaN
# 1                                          No
# 2                                          No
# 3                                          No
# 4                                          No
#
#    specs_dimensions_capacity_front_tread  \
# 0                                    NaN
# 1                                 1280mm
# 2                                    NaN
# 3                                 1400mm
# 4                                    NaN
#
#    specs_dimensions_capacity_rear_tread  \
# 0                                   NaN
# 1                                1290mm
# 2                                   NaN
# 3                                1385mm
# 4                                   NaN
#
#   specs_dimensions_capacity_gross_weight specs_miscellaneous_turning_radius  \
# 0                                    NaN                                NaN
# 1                                 1540kg                         4.5 metres
# 2                                    NaN                                5.0
# 3                                    NaN                         4.7 metres
# 4                                    NaN                         5.1 meters
#
#   specs_miscellaneous_top_speed specs_miscellaneous_acceleration  \
# 0                           NaN                              NaN
# 1                      145 Kmph                     15.7 Seconds
# 2                           NaN                             11.7
# 3                      165 Kmph                     14.3 Seconds
# 4                      172 Kmph                     13.7 Seconds
#
#   specs_engine_and_transmission_borex_stroke  \
# 0                                        NaN
# 1                                        NaN
# 2                                72.2 x 81.3
# 3                                        NaN
# 4                                        NaN
#
#   specs_dimensions_capacity_ground_clearance_unladen
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 77 columns]

# %%
# Specify the full path with the filename, not just the directory
output_path = r"C:\Users\Shiva\OneDrive\Desktop\cardekho\Dataset-20241106T053909Z-001\Dataset\processed_car_data_chennai.csv"

# Save the DataFrame to the specified path
df_chennai.to_csv(output_path, index=False)

print(f"CSV file has been exported to '{output_path}'")
# Out:
# CSV file has been exported to 'C:\Users\Shiva\OneDrive\Desktop\cardekho\Dataset-20241106T053909Z-001\Dataset\processed_car_data_chennai.csv'

# %%
def parse_json_safely(text: str) -> Dict:
    """
    Safely parse JSON string with multiple fallback methods
    """
    if not isinstance(text, str):
        return {}
    
    text = text.strip()
    if not text:
        return {}
        
    try:
        return json.loads(text)
    except json.JSONDecodeError:
        try:
            return ast.literal_eval(text)
        except:
            return {}

def extract_car_details(json_data: Dict) -> Dict[str, Any]:
    """
    Extract information from new_car_detail section
    """
    result = {}
    
    # Direct fields we want to extract
    fields = ['ft', 'bt', 'km', 'transmission', 'ownerNo', 'owner', 
              'oem', 'model', 'modelYear','centralVariantId', 'variantName', 'price', 'priceFixedText', 'trendingText']
    
    for field in fields:
        if field in json_data:
            result[f'detail_{field}'] = json_data[field]
    
    return result

def extract_car_overview(json_data: Dict) -> Dict[str, Any]:
    """
    Extract information from new_car_overview section
    """
    result = {}
    
    if 'top' in json_data and isinstance(json_data['top'], list):
        for item in json_data['top']:
            if isinstance(item, dict) and 'key' in item and 'value' in item:
                key = item['key'].lower().replace(' ', '_').replace('(', '').replace(')', '')
                result[f'overview_{key}'] = item['value']
    
    return result

def extract_car_features(json_data: Dict) -> Dict[str, Any]:
    """
    Extract information from new_car_feature section
    """
    result = {}
    
    # Extract top features
    if 'top' in json_data and isinstance(json_data['top'], list):
        top_features = [item.get('value', '') for item in json_data['top'] if isinstance(item, dict)]
        result['feature_top'] = ', '.join(filter(None, top_features))
    
    # Extract detailed features by category
    if 'data' in json_data and isinstance(json_data['data'], list):
        for category in json_data['data']:
            if isinstance(category, dict) and 'heading' in category and 'list' in category:
                category_name = category['heading'].lower().replace(' & ', '_').replace(' ', '_')
                features = [item.get('value', '') for item in category['list'] if isinstance(item, dict)]
                result[f'feature_{category_name}'] = ', '.join(filter(None, features))
    
    return result

def extract_car_specs(json_data: Dict) -> Dict[str, Any]:
    """
    Extract information from new_car_specs section with proper handling of the nested structure
    """
    result = {}
    
    # Process top-level specifications if present
    if 'top' in json_data and isinstance(json_data['top'], list):
        for item in json_data['top']:
            if isinstance(item, dict) and 'key' in item and 'value' in item:
                clean_key = item['key'].lower().replace(' ', '_').replace('(', '').replace(')', '')
                result[f'specs_top_{clean_key}'] = item['value']
    
    # Process detailed specifications in the data section
    if 'data' in json_data and isinstance(json_data['data'], list):
        for category in json_data['data']:
            if isinstance(category, dict) and 'heading' in category and 'list' in category:
                # Clean the category name
                category_name = category['heading'].lower().replace(' & ', '_').replace(' ', '_')
                
                # Process the specifications list
                if isinstance(category['list'], list):
                    # Store each specification as an individual column
                    for item in category['list']:
                        if isinstance(item, dict) and 'key' in item and 'value' in item:
                            clean_key = item['key'].lower().replace(' ', '_').replace('(', '').replace(')', '')
                            result[f'specs_{category_name}_{clean_key}'] = item['value']
                    
                    # Also store the complete JSON for the category
                    result[f'specs_{category_name}_json'] = json.dumps(category['list'])
    
    return result

def process_excel_files(file_paths: List[str], output_csv: str) -> pd.DataFrame:
    """
    Process Excel files containing car data with location verification
    """
    all_data = []
    
    for file_path in file_paths:
        # Extract city name from file path
        city_name = Path(file_path).stem.split('_')[0].capitalize()
        print(f"\nProcessing {city_name} data from {file_path}...")
        
        try:
            # Read Excel file
            df = pd.read_excel(file_path)
            print(f"Initial data shape for {city_name}: {df.shape}")
            
            # Add city column if not present
            if 'city' not in df.columns:
                df['city'] = city_name
            
            # Process each row
            for idx, row in df.iterrows():
                processed_row = {
                    'file_name': Path(file_path).name,
                    'row_index': idx,
                    'source_city': city_name  # Add explicit source city tracking
                }
                
                try:
                    # Store location information
                    processed_row['city'] = row.get('city', city_name)
                    if 'location' in row:
                        processed_row['location'] = row['location']
                    
                    # Process specs data
                    if 'new_car_specs' in row and pd.notna(row['new_car_specs']):
                        specs_data = row['new_car_specs']
                        if isinstance(specs_data, str):
                            try:
                                specs_dict = json.loads(specs_data)
                            except json.JSONDecodeError:
                                try:
                                    specs_dict = ast.literal_eval(specs_data)
                                except:
                                    print(f"Error parsing new_car_specs in row {idx}")
                                    specs_dict = {}
                        else:
                            specs_dict = specs_data
                            
                        if specs_dict:
                            specs_result = extract_car_specs(specs_dict)
                            processed_row.update(specs_result)
                    
                    # Process other JSON columns
                    if 'new_car_detail' in row:
                        json_data = parse_json_safely(row['new_car_detail'])
                        processed_row.update(extract_car_details(json_data))
                    
                    if 'new_car_overview' in row:
                        json_data = parse_json_safely(row['new_car_overview'])
                        processed_row.update(extract_car_overview(json_data))
                    
                    if 'new_car_feature' in row:
                        json_data = parse_json_safely(row['new_car_feature'])
                        processed_row.update(extract_car_features(json_data))
                    
                    # Add any non-JSON columns
                    for col in df.columns:
                        if col not in ['new_car_detail', 'new_car_overview', 'new_car_feature', 'new_car_specs']:
                            processed_row[col] = row[col]
                    
                except Exception as e:
                    print(f"Error processing row {idx} in {city_name} data: {str(e)}")
                    continue
                
                all_data.append(processed_row)
                
        except Exception as e:
            print(f"Error processing file {file_path}: {str(e)}")
            continue
    
    # Create final DataFrame
    final_df = pd.DataFrame(all_data)
    
    # Verify data by city
    print("\nData verification by city:")
    print(final_df['source_city'].value_counts())
    
    # Save to CSV
    if output_csv:
        final_df.to_csv(output_csv, index=False)
        print(f"\nSaved processed data to {output_csv}")
        
        # Print column summary by city
        print("\nColumn Summary by City:")
        for city in final_df['source_city'].unique():
            city_df = final_df[final_df['source_city'] == city]
            print(f"\n{city} Data Summary:")
            print(f"Total rows: {len(city_df)}")
            
            categories = ['detail_', 'overview_', 'feature_', 'specs_']
            for prefix in categories:
                cols = [col for col in city_df.columns if col.startswith(prefix)]
                if cols:
                    print(f"\n{prefix.upper()} columns in {city}:")
                    for col in sorted(cols):
                        non_null_count = city_df[col].notna().sum()
                        print(f"- {col} ({non_null_count} non-null values)")
    
    return final_df

def main():
    """
    Main function to execute the processing for multiple cities
    """
    excel_files = [
        r"C:\Users\Shiva\OneDrive\Desktop\cardekho\Dataset-20241106T053909Z-001\Dataset\delhi_cars.xlsx"
    ]
    output_path = "processed_car_data_delhi.csv"
    
    try:
        # Process files
        result_df = process_excel_files(excel_files, output_path)
        
        # Display statistics by city
        for city in result_df['source_city'].unique():
            city_df = result_df[result_df['source_city'] == city]
            print(f"\nStatistics for {city}:")
            print(f"Total cars: {len(city_df)}")
            
            if 'detail_price' in city_df.columns:
                print(f"\nPrice Distribution in {city}:")
                print(city_df['detail_price'].value_counts().head())
            
            if 'detail_modelYear' in city_df.columns:
                print(f"\nModel Year Distribution in {city}:")
                print(city_df['detail_modelYear'].value_counts().sort_index().head())
            
            if 'detail_transmission' in city_df.columns:
                print(f"\nTransmission Types in {city}:")
                print(city_df['detail_transmission'].value_counts())
            
            print("\n" + "="*50)
        
        # Save separate CSV files for each city
        for city in result_df['source_city'].unique():
            city_df = result_df[result_df['source_city'] == city]
            city_output = f"processed_car_data_{city.lower()}.csv"
            city_df.to_csv(city_output, index=False)
            print(f"\nSaved {city} data to {city_output}")
            
    except Exception as e:
        print(f"Error in main execution: {str(e)}")

if __name__ == "__main__":
    main()
# Out:
# Processing Delhi data from C:\Users\Shiva\OneDrive\Desktop\cardekho\Dataset-20241106T053909Z-001\Dataset\delhi_cars.xlsx...
# Initial data shape for Delhi: (1485, 5)
#
# Data verification by city:
# source_city
# Delhi    1485
# Name: count, dtype: int64
#
# Saved processed data to processed_car_data_delhi.csv
#
# Column Summary by City:
#
# Delhi Data Summary:
# Total rows: 1485
#
# DETAIL_ columns in Delhi:
# - detail_bt (1485 non-null values)
# - detail_centralVariantId (1485 non-null values)
# - detail_ft (1485 non-null values)
# - detail_km (1485 non-null values)
# - detail_model (1485 non-null values)
# - detail_modelYear (1485 non-null values)
# - detail_oem (1485 non-null values)
# - detail_owner (1485 non-null values)
# - detail_ownerNo (1485 non-null values)
# - detail_price (1485 non-null values)
# - detail_priceFixedText (0 non-null values)
# - detail_transmission (1485 non-null values)
# - detail_trendingText (1485 non-null values)
# - detail_variantName (1485 non-null values)
#
# OVERVIEW_ columns in Delhi:
# - overview_engine_displacement (1485 non-null values)
# - overview_fuel_type (1485 non-null values)
# - overview_insurance_validity (1484 non-null values)
# - overview_kms_driven (1485 non-null values)
# - overview_ownership (1480 non-null values)
# - overview_registration_year (1480 non-null values)
# - overview_rto (1341 non-null values)
# - overview_seats (1484 non-null values)
# - overview_transmission (1485 non-null values)
# - overview_year_of_manufacture (1485 non-null values)
#
# FEATURE_ columns in Delhi:
# - feature_comfort_convenience (1481 non-null values)
# - feature_entertainment_communication (1297 non-null values)
# - feature_exterior (1481 non-null values)
# - feature_interior (1480 non-null values)
# - feature_safety (1478 non-null values)
# - feature_top (1485 non-null values)
#
# SPECS_ columns in Delhi:
# - specs_dimensions_capacity_front_tread (844 non-null values)
# - specs_dimensions_capacity_gross_weight (700 non-null values)
# - specs_dimensions_capacity_ground_clearance_unladen (72 non-null values)
# - specs_dimensions_capacity_height (1477 non-null values)
# - specs_dimensions_capacity_json (1484 non-null values)
# - specs_dimensions_capacity_kerb_weight (1479 non-null values)
# - specs_dimensions_capacity_length (1477 non-null values)
# - specs_dimensions_capacity_rear_tread (841 non-null values)
# - specs_dimensions_capacity_wheel_base (1461 non-null values)
# - specs_dimensions_capacity_width (1474 non-null values)
# - specs_engine_and_transmission_borex_stroke (419 non-null values)
# - specs_engine_and_transmission_color (1485 non-null values)
# - specs_engine_and_transmission_compression_ratio (324 non-null values)
# - specs_engine_and_transmission_displacement (1485 non-null values)
# - specs_engine_and_transmission_engine_type (1442 non-null values)
# - specs_engine_and_transmission_fuel_suppy_system (1160 non-null values)
# - specs_engine_and_transmission_json (1485 non-null values)
# - specs_engine_and_transmission_max_power (1482 non-null values)
# - specs_engine_and_transmission_max_torque (1482 non-null values)
# - specs_engine_and_transmission_no_of_cylinder (1482 non-null values)
# - specs_engine_and_transmission_super_charger (1105 non-null values)
# - specs_engine_and_transmission_turbo_charger (1301 non-null values)
# - specs_engine_and_transmission_value_configuration (1076 non-null values)
# - specs_engine_and_transmission_values_per_cylinder (1479 non-null values)
# - specs_miscellaneous_acceleration (880 non-null values)
# - specs_miscellaneous_alloy_wheel_size (965 non-null values)
# - specs_miscellaneous_cargo_volumn (1198 non-null values)
# - specs_miscellaneous_drive_type (1250 non-null values)
# - specs_miscellaneous_front_brake_type (1469 non-null values)
# - specs_miscellaneous_gear_box (1475 non-null values)
# - specs_miscellaneous_json (1485 non-null values)
# - specs_miscellaneous_no_door_numbers (1483 non-null values)
# - specs_miscellaneous_rear_brake_type (1469 non-null values)
# - specs_miscellaneous_seating_capacity (1484 non-null values)
# - specs_miscellaneous_steering_type (1431 non-null values)
# - specs_miscellaneous_top_speed (840 non-null values)
# - specs_miscellaneous_turning_radius (1175 non-null values)
# - specs_miscellaneous_tyre_type (1465 non-null values)
# - specs_top_engine (1485 non-null values)
# - specs_top_max_power (1482 non-null values)
# - specs_top_mileage (1401 non-null values)
# - specs_top_seats (1485 non-null values)
# - specs_top_torque (1482 non-null values)
# - specs_top_wheel_size (965 non-null values)
#
# Statistics for Delhi:
# Total cars: 1485
#
# Price Distribution in Delhi:
# detail_price
# ₹ 3.50 Lakh     14
# ₹ 3 Lakh        14
# ₹ 5.25 Lakh     13
# ₹ 16.50 Lakh    11
# ₹ 5.50 Lakh     11
# Name: count, dtype: int64
#
# Model Year Distribution in Delhi:
# detail_modelYear
# 2006     4
# 2007     1
# 2008     4
# 2009    26
# 2010    30
# Name: count, dtype: int64
#
# Transmission Types in Delhi:
# detail_transmission
# Manual       942
# Automatic    543
# Name: count, dtype: int64
#
# ==================================================
#
# Saved Delhi data to processed_car_data_delhi.csv

# %%
df_delhi= pd.read_csv("processed_car_data_delhi.csv")
df_delhi.head()
# Out:
#          file_name  row_index source_city   city specs_top_mileage  \
# 0  delhi_cars.xlsx          0       Delhi  Delhi           18 kmpl
# 1  delhi_cars.xlsx          1       Delhi  Delhi        15.29 kmpl
# 2  delhi_cars.xlsx          2       Delhi  Delhi        12.74 kmpl
# 3  delhi_cars.xlsx          3       Delhi  Delhi        22.38 kmpl
# 4  delhi_cars.xlsx          4       Delhi  Delhi        15.29 kmpl
#
#   specs_top_engine specs_top_max_power specs_top_torque specs_top_wheel_size  \
# 0          1493 CC           113.43bhp            250Nm                   17
# 1          1591 CC            121.3bhp            151Nm                  NaN
# 2          1991 CC              197bhp            320nm                   19
# 3          1197 CC            88.50bhp            113Nm                  NaN
# 4          1591 CC            121.3bhp            151Nm                  NaN
#
#    specs_top_seats  ... specs_miscellaneous_turning_radius  \
# 0              5.0  ...                                NaN
# 1              5.0  ...                         5.3 metres
# 2              5.0  ...                                NaN
# 3              5.0  ...                                4.8
# 4              5.0  ...                         5.3 metres
#
#   specs_miscellaneous_top_speed  specs_miscellaneous_acceleration  \
# 0                           NaN                               NaN
# 1                      165 Kmph                      10.5 Seconds
# 2                      217 Kmph                               NaN
# 3                           NaN                               NaN
# 4                      165 Kmph                      10.5 Seconds
#
#   overview_rto specs_dimensions_capacity_gross_weight  \
# 0          NaN                                    NaN
# 1         HR51                                    NaN
# 2         DL01                                 2360kg
# 3         DL4C                                   1335
# 4         DL8C                                    NaN
#
#    specs_dimensions_capacity_front_tread  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                   1530
# 4                                    NaN
#
#    specs_dimensions_capacity_rear_tread  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                  1530
# 4                                   NaN
#
#   specs_engine_and_transmission_borex_stroke  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#   specs_engine_and_transmission_compression_ratio  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
#   specs_dimensions_capacity_ground_clearance_unladen
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 79 columns]

# %%
# Specify the full path with the filename, not just the directory
output_path = r"C:\Users\Shiva\OneDrive\Desktop\cardekho\Dataset-20241106T053909Z-001\Dataset\processed_car_data_delhi.csv"

# Save the DataFrame to the specified path
df_delhi.to_csv(output_path, index=False)

print(f"CSV file has been exported to '{output_path}'")
# Out:
# CSV file has been exported to 'C:\Users\Shiva\OneDrive\Desktop\cardekho\Dataset-20241106T053909Z-001\Dataset\processed_car_data_delhi.csv'

# %%
def parse_json_safely(text: str) -> Dict:
    """
    Safely parse JSON string with multiple fallback methods
    """
    if not isinstance(text, str):
        return {}
    
    text = text.strip()
    if not text:
        return {}
        
    try:
        return json.loads(text)
    except json.JSONDecodeError:
        try:
            return ast.literal_eval(text)
        except:
            return {}

def extract_car_details(json_data: Dict) -> Dict[str, Any]:
    """
    Extract information from new_car_detail section
    """
    result = {}
    
    # Direct fields we want to extract
    fields = ['ft', 'bt', 'km', 'transmission', 'ownerNo', 'owner', 
              'oem', 'model', 'modelYear','centralVariantId', 'variantName', 'price', 'priceFixedText', 'trendingText']
    
    for field in fields:
        if field in json_data:
            result[f'detail_{field}'] = json_data[field]
    
    return result

def extract_car_overview(json_data: Dict) -> Dict[str, Any]:
    """
    Extract information from new_car_overview section
    """
    result = {}
    
    if 'top' in json_data and isinstance(json_data['top'], list):
        for item in json_data['top']:
            if isinstance(item, dict) and 'key' in item and 'value' in item:
                key = item['key'].lower().replace(' ', '_').replace('(', '').replace(')', '')
                result[f'overview_{key}'] = item['value']
    
    return result

def extract_car_features(json_data: Dict) -> Dict[str, Any]:
    """
    Extract information from new_car_feature section
    """
    result = {}
    
    # Extract top features
    if 'top' in json_data and isinstance(json_data['top'], list):
        top_features = [item.get('value', '') for item in json_data['top'] if isinstance(item, dict)]
        result['feature_top'] = ', '.join(filter(None, top_features))
    
    # Extract detailed features by category
    if 'data' in json_data and isinstance(json_data['data'], list):
        for category in json_data['data']:
            if isinstance(category, dict) and 'heading' in category and 'list' in category:
                category_name = category['heading'].lower().replace(' & ', '_').replace(' ', '_')
                features = [item.get('value', '') for item in category['list'] if isinstance(item, dict)]
                result[f'feature_{category_name}'] = ', '.join(filter(None, features))
    
    return result

def extract_car_specs(json_data: Dict) -> Dict[str, Any]:
    """
    Extract information from new_car_specs section with proper handling of the nested structure
    """
    result = {}
    
    # Process top-level specifications if present
    if 'top' in json_data and isinstance(json_data['top'], list):
        for item in json_data['top']:
            if isinstance(item, dict) and 'key' in item and 'value' in item:
                clean_key = item['key'].lower().replace(' ', '_').replace('(', '').replace(')', '')
                result[f'specs_top_{clean_key}'] = item['value']
    
    # Process detailed specifications in the data section
    if 'data' in json_data and isinstance(json_data['data'], list):
        for category in json_data['data']:
            if isinstance(category, dict) and 'heading' in category and 'list' in category:
                # Clean the category name
                category_name = category['heading'].lower().replace(' & ', '_').replace(' ', '_')
                
                # Process the specifications list
                if isinstance(category['list'], list):
                    # Store each specification as an individual column
                    for item in category['list']:
                        if isinstance(item, dict) and 'key' in item and 'value' in item:
                            clean_key = item['key'].lower().replace(' ', '_').replace('(', '').replace(')', '')
                            result[f'specs_{category_name}_{clean_key}'] = item['value']
                    
                    # Also store the complete JSON for the category
                    result[f'specs_{category_name}_json'] = json.dumps(category['list'])
    
    return result

def process_excel_files(file_paths: List[str], output_csv: str) -> pd.DataFrame:
    """
    Process Excel files containing car data with location verification
    """
    all_data = []
    
    for file_path in file_paths:
        # Extract city name from file path
        city_name = Path(file_path).stem.split('_')[0].capitalize()
        print(f"\nProcessing {city_name} data from {file_path}...")
        
        try:
            # Read Excel file
            df = pd.read_excel(file_path)
            print(f"Initial data shape for {city_name}: {df.shape}")
            
            # Add city column if not present
            if 'city' not in df.columns:
                df['city'] = city_name
            
            # Process each row
            for idx, row in df.iterrows():
                processed_row = {
                    'file_name': Path(file_path).name,
                    'row_index': idx,
                    'source_city': city_name  # Add explicit source city tracking
                }
                
                try:
                    # Store location information
                    processed_row['city'] = row.get('city', city_name)
                    if 'location' in row:
                        processed_row['location'] = row['location']
                    
                    # Process specs data
                    if 'new_car_specs' in row and pd.notna(row['new_car_specs']):
                        specs_data = row['new_car_specs']
                        if isinstance(specs_data, str):
                            try:
                                specs_dict = json.loads(specs_data)
                            except json.JSONDecodeError:
                                try:
                                    specs_dict = ast.literal_eval(specs_data)
                                except:
                                    print(f"Error parsing new_car_specs in row {idx}")
                                    specs_dict = {}
                        else:
                            specs_dict = specs_data
                            
                        if specs_dict:
                            specs_result = extract_car_specs(specs_dict)
                            processed_row.update(specs_result)
                    
                    # Process other JSON columns
                    if 'new_car_detail' in row:
                        json_data = parse_json_safely(row['new_car_detail'])
                        processed_row.update(extract_car_details(json_data))
                    
                    if 'new_car_overview' in row:
                        json_data = parse_json_safely(row['new_car_overview'])
                        processed_row.update(extract_car_overview(json_data))
                    
                    if 'new_car_feature' in row:
                        json_data = parse_json_safely(row['new_car_feature'])
                        processed_row.update(extract_car_features(json_data))
                    
                    # Add any non-JSON columns
                    for col in df.columns:
                        if col not in ['new_car_detail', 'new_car_overview', 'new_car_feature', 'new_car_specs']:
                            processed_row[col] = row[col]
                    
                except Exception as e:
                    print(f"Error processing row {idx} in {city_name} data: {str(e)}")
                    continue
                
                all_data.append(processed_row)
                
        except Exception as e:
            print(f"Error processing file {file_path}: {str(e)}")
            continue
    
    # Create final DataFrame
    final_df = pd.DataFrame(all_data)
    
    # Verify data by city
    print("\nData verification by city:")
    print(final_df['source_city'].value_counts())
    
    # Save to CSV
    if output_csv:
        final_df.to_csv(output_csv, index=False)
        print(f"\nSaved processed data to {output_csv}")
        
        # Print column summary by city
        print("\nColumn Summary by City:")
        for city in final_df['source_city'].unique():
            city_df = final_df[final_df['source_city'] == city]
            print(f"\n{city} Data Summary:")
            print(f"Total rows: {len(city_df)}")
            
            categories = ['detail_', 'overview_', 'feature_', 'specs_']
            for prefix in categories:
                cols = [col for col in city_df.columns if col.startswith(prefix)]
                if cols:
                    print(f"\n{prefix.upper()} columns in {city}:")
                    for col in sorted(cols):
                        non_null_count = city_df[col].notna().sum()
                        print(f"- {col} ({non_null_count} non-null values)")
    
    return final_df

def main():
    """
    Main function to execute the processing for multiple cities
    """
    excel_files = [
        r"C:\Users\Shiva\OneDrive\Desktop\cardekho\Dataset-20241106T053909Z-001\Dataset\hyderabad_cars.xlsx" 
    ]
    output_path = "processed_car_data_hyderabad.csv"
    
    try:
        # Process files
        result_df = process_excel_files(excel_files, output_path)
        
        # Display statistics by city
        for city in result_df['source_city'].unique():
            city_df = result_df[result_df['source_city'] == city]
            print(f"\nStatistics for {city}:")
            print(f"Total cars: {len(city_df)}")
            
            if 'detail_price' in city_df.columns:
                print(f"\nPrice Distribution in {city}:")
                print(city_df['detail_price'].value_counts().head())
            
            if 'detail_modelYear' in city_df.columns:
                print(f"\nModel Year Distribution in {city}:")
                print(city_df['detail_modelYear'].value_counts().sort_index().head())
            
            if 'detail_transmission' in city_df.columns:
                print(f"\nTransmission Types in {city}:")
                print(city_df['detail_transmission'].value_counts())
            
            print("\n" + "="*50)
        
        # Save separate CSV files for each city
        for city in result_df['source_city'].unique():
            city_df = result_df[result_df['source_city'] == city]
            city_output = f"processed_car_data_{city.lower()}.csv"
            city_df.to_csv(city_output, index=False)
            print(f"\nSaved {city} data to {city_output}")
            
    except Exception as e:
        print(f"Error in main execution: {str(e)}")

if __name__ == "__main__":
    main()
# Out:
# Processing Hyderabad data from C:\Users\Shiva\OneDrive\Desktop\cardekho\Dataset-20241106T053909Z-001\Dataset\hyderabad_cars.xlsx...
# Initial data shape for Hyderabad: (1483, 5)
#
# Data verification by city:
# source_city
# Hyderabad    1483
# Name: count, dtype: int64
#
# Saved processed data to processed_car_data_hyderabad.csv
#
# Column Summary by City:
#
# Hyderabad Data Summary:
# Total rows: 1483
#
# DETAIL_ columns in Hyderabad:
# - detail_bt (1483 non-null values)
# - detail_centralVariantId (1483 non-null values)
# - detail_ft (1483 non-null values)
# - detail_km (1483 non-null values)
# - detail_model (1483 non-null values)
# - detail_modelYear (1483 non-null values)
# - detail_oem (1483 non-null values)
# - detail_owner (1483 non-null values)
# - detail_ownerNo (1483 non-null values)
# - detail_price (1483 non-null values)
# - detail_priceFixedText (0 non-null values)
# - detail_transmission (1483 non-null values)
# - detail_trendingText (1483 non-null values)
# - detail_variantName (1483 non-null values)
#
# OVERVIEW_ columns in Hyderabad:
# - overview_engine_displacement (1482 non-null values)
# - overview_fuel_type (1483 non-null values)
# - overview_insurance_validity (1483 non-null values)
# - overview_kms_driven (1482 non-null values)
# - overview_ownership (1483 non-null values)
# - overview_registration_year (1477 non-null values)
# - overview_rto (1365 non-null values)
# - overview_seats (1483 non-null values)
# - overview_transmission (1483 non-null values)
# - overview_year_of_manufacture (1477 non-null values)
#
# FEATURE_ columns in Hyderabad:
# - feature_comfort_convenience (1473 non-null values)
# - feature_entertainment_communication (1297 non-null values)
# - feature_exterior (1468 non-null values)
# - feature_interior (1471 non-null values)
# - feature_safety (1468 non-null values)
# - feature_top (1483 non-null values)
#
# SPECS_ columns in Hyderabad:
# - specs_dimensions_capacity_front_tread (831 non-null values)
# - specs_dimensions_capacity_gross_weight (686 non-null values)
# - specs_dimensions_capacity_ground_clearance_unladen (106 non-null values)
# - specs_dimensions_capacity_height (1472 non-null values)
# - specs_dimensions_capacity_json (1477 non-null values)
# - specs_dimensions_capacity_kerb_weight (1473 non-null values)
# - specs_dimensions_capacity_length (1472 non-null values)
# - specs_dimensions_capacity_rear_tread (831 non-null values)
# - specs_dimensions_capacity_wheel_base (1459 non-null values)
# - specs_dimensions_capacity_width (1472 non-null values)
# - specs_engine_and_transmission_borex_stroke (436 non-null values)
# - specs_engine_and_transmission_color (1482 non-null values)
# - specs_engine_and_transmission_compression_ratio (334 non-null values)
# - specs_engine_and_transmission_displacement (1482 non-null values)
# - specs_engine_and_transmission_engine_type (1431 non-null values)
# - specs_engine_and_transmission_fuel_suppy_system (1150 non-null values)
# - specs_engine_and_transmission_json (1482 non-null values)
# - specs_engine_and_transmission_max_power (1472 non-null values)
# - specs_engine_and_transmission_max_torque (1472 non-null values)
# - specs_engine_and_transmission_no_of_cylinder (1475 non-null values)
# - specs_engine_and_transmission_super_charger (1128 non-null values)
# - specs_engine_and_transmission_turbo_charger (1266 non-null values)
# - specs_engine_and_transmission_value_configuration (1085 non-null values)
# - specs_engine_and_transmission_values_per_cylinder (1473 non-null values)
# - specs_miscellaneous_acceleration (797 non-null values)
# - specs_miscellaneous_alloy_wheel_size (913 non-null values)
# - specs_miscellaneous_cargo_volumn (1203 non-null values)
# - specs_miscellaneous_drive_type (1176 non-null values)
# - specs_miscellaneous_front_brake_type (1470 non-null values)
# - specs_miscellaneous_gear_box (1466 non-null values)
# - specs_miscellaneous_json (1483 non-null values)
# - specs_miscellaneous_no_door_numbers (1483 non-null values)
# - specs_miscellaneous_rear_brake_type (1470 non-null values)
# - specs_miscellaneous_seating_capacity (1483 non-null values)
# - specs_miscellaneous_steering_type (1433 non-null values)
# - specs_miscellaneous_top_speed (766 non-null values)
# - specs_miscellaneous_turning_radius (1234 non-null values)
# - specs_miscellaneous_tyre_type (1470 non-null values)
# - specs_top_engine (1482 non-null values)
# - specs_top_max_power (1472 non-null values)
# - specs_top_mileage (1441 non-null values)
# - specs_top_seats (1483 non-null values)
# - specs_top_torque (1472 non-null values)
# - specs_top_wheel_size (913 non-null values)
#
# Statistics for Hyderabad:
# Total cars: 1483
#
# Price Distribution in Hyderabad:
# detail_price
# ₹ 7.50 Lakh    22
# ₹ 4 Lakh       21
# ₹ 6.50 Lakh    20
# ₹ 6 Lakh       19
# ₹ 4.50 Lakh    17
# Name: count, dtype: int64
#
# Model Year Distribution in Hyderabad:
# detail_modelYear
# 1985    1
# 1997    1
# 2001    4
# 2002    2
# 2003    5
# Name: count, dtype: int64
#
# Transmission Types in Hyderabad:
# detail_transmission
# Manual       1106
# Automatic     377
# Name: count, dtype: int64
#
# ==================================================
#
# Saved Hyderabad data to processed_car_data_hyderabad.csv

# %%
df_hyderabad= pd.read_csv("processed_car_data_hyderabad.csv")
df_hyderabad.head()
# Out:
#              file_name  row_index source_city       city specs_top_mileage  \
# 0  hyderabad_cars.xlsx          0   Hyderabad  Hyderabad        16.47 kmpl
# 1  hyderabad_cars.xlsx          1   Hyderabad  Hyderabad         21.1 kmpl
# 2  hyderabad_cars.xlsx          2   Hyderabad  Hyderabad               NaN
# 3  hyderabad_cars.xlsx          3   Hyderabad  Hyderabad         21.4 kmpl
# 4  hyderabad_cars.xlsx          4   Hyderabad  Hyderabad               NaN
#
#   specs_top_engine specs_top_max_power specs_top_torque specs_top_wheel_size  \
# 0           999 CC           108.62bhp            175nm                  R16
# 1           814 CC             55.2bhp           74.5Nm                  NaN
# 2          1197 CC            81.80bhp          113.8Nm                  NaN
# 3          1197 CC             83.1bhp            115Nm                   16
# 4          1997 CC              150bhp            320Nm                   18
#
#    specs_top_seats  ...                                        feature_top  \
# 0                5  ...  Power Steering, Power Windows Front, Air Condi...
# 1                5  ...  Power Steering, Power Windows Front, Air Condi...
# 2                5  ...  Power Steering, Power Windows Front, Air Condi...
# 3                5  ...  Power Steering, Power Windows Front, Air Condi...
# 4                4  ...  Power Steering, Power Windows Front, Air Condi...
#
#                          feature_comfort_convenience  \
# 0  Power Steering, Power Windows Front, Power Win...
# 1  Power Steering, Power Windows Front, Remote Tr...
# 2  Power Steering, Power Windows Front, Power Win...
# 3  Power Steering, Power Windows Front, Power Win...
# 4  Power Steering, Power Windows Front, Low Fuel ...
#
#                                     feature_interior  \
# 0  Air Conditioner, Heater, Adjustable Steering, ...
# 1  Air Conditioner, Heater, Digital Odometer, Ele...
# 2  Air Conditioner, Heater, Adjustable Steering, ...
# 3  Air Conditioner, Heater, Adjustable Steering, ...
# 4  Air Conditioner, Heater, Adjustable Steering, ...
#
#                                     feature_exterior  \
# 0  Adjustable Head Lights, Fog Lights Front, Fog ...
# 1  Adjustable Head Lights, Manually Adjustable Ex...
# 2  Adjustable Head Lights, Power Adjustable Exter...
# 3  Adjustable Head Lights, Fog Lights Front, Powe...
# 4  Adjustable Head Lights, Fog Lights Front, Powe...
#
#                                       feature_safety  \
# 0  Anti Lock Braking System, Centeral Locking, Po...
# 1  Child Safety Locks, Driver Air Bag, Day Night ...
# 2  Anti Lock Braking System, Brake Assist, Center...
# 3  Anti Lock Braking System, Centeral Locking, Po...
# 4  Anti Lock Braking System, Brake Assist, Center...
#
#                  feature_entertainment_communication  \
# 0  Radio, Speakers Front, Speakers Rear, Usb Auxi...
# 1                                                NaN
# 2  Radio, Speakers Front, Speakers Rear, Integrat...
# 3  Radio, Audio System Remote Control, Speakers F...
# 4  Radio, Speakers Front, Speakers Rear, Integrat...
#
#                                            car_links  \
# 0  https://www.cardekho.com/used-car-details/used...
# 1  https://www.cardekho.com/buy-used-car-details/...
# 2  https://www.cardekho.com/used-car-details/used...
# 3  https://www.cardekho.com/buy-used-car-details/...
# 4  https://www.cardekho.com/used-car-details/used...
#
#   specs_miscellaneous_top_speed specs_miscellaneous_acceleration  \
# 0                           NaN                              NaN
# 1                      135 Kmph                       19 Seconds
# 2                           NaN                              NaN
# 3                      180 Kmph                    12.36 seconds
# 4                           NaN                              NaN
#
#   specs_dimensions_capacity_ground_clearance_unladen
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 79 columns]

# %%
# Specify the full path with the filename, not just the directory
output_path = r"C:\Users\Shiva\OneDrive\Desktop\cardekho\Dataset-20241106T053909Z-001\Dataset\processed_car_data_hyderabad.csv"

# Save the DataFrame to the specified path
df_hyderabad.to_csv(output_path, index=False)

print(f"CSV file has been exported to '{output_path}'")
# Out:
# CSV file has been exported to 'C:\Users\Shiva\OneDrive\Desktop\cardekho\Dataset-20241106T053909Z-001\Dataset\processed_car_data_hyderabad.csv'

# %%
def parse_json_safely(text: str) -> Dict:
    """
    Safely parse JSON string with multiple fallback methods
    """
    if not isinstance(text, str):
        return {}
    
    text = text.strip()
    if not text:
        return {}
        
    try:
        return json.loads(text)
    except json.JSONDecodeError:
        try:
            return ast.literal_eval(text)
        except:
            return {}

def extract_car_details(json_data: Dict) -> Dict[str, Any]:
    """
    Extract information from new_car_detail section
    """
    result = {}
    
    # Direct fields we want to extract
    fields = ['ft', 'bt', 'km', 'transmission', 'ownerNo', 'owner', 
              'oem', 'model', 'modelYear','centralVariantId', 'variantName', 'price', 'priceFixedText', 'trendingText']
    
    for field in fields:
        if field in json_data:
            result[f'detail_{field}'] = json_data[field]
    
    return result

def extract_car_overview(json_data: Dict) -> Dict[str, Any]:
    """
    Extract information from new_car_overview section
    """
    result = {}
    
    if 'top' in json_data and isinstance(json_data['top'], list):
        for item in json_data['top']:
            if isinstance(item, dict) and 'key' in item and 'value' in item:
                key = item['key'].lower().replace(' ', '_').replace('(', '').replace(')', '')
                result[f'overview_{key}'] = item['value']
    
    return result

def extract_car_features(json_data: Dict) -> Dict[str, Any]:
    """
    Extract information from new_car_feature section
    """
    result = {}
    
    # Extract top features
    if 'top' in json_data and isinstance(json_data['top'], list):
        top_features = [item.get('value', '') for item in json_data['top'] if isinstance(item, dict)]
        result['feature_top'] = ', '.join(filter(None, top_features))
    
    # Extract detailed features by category
    if 'data' in json_data and isinstance(json_data['data'], list):
        for category in json_data['data']:
            if isinstance(category, dict) and 'heading' in category and 'list' in category:
                category_name = category['heading'].lower().replace(' & ', '_').replace(' ', '_')
                features = [item.get('value', '') for item in category['list'] if isinstance(item, dict)]
                result[f'feature_{category_name}'] = ', '.join(filter(None, features))
    
    return result

def extract_car_specs(json_data: Dict) -> Dict[str, Any]:
    """
    Extract information from new_car_specs section with proper handling of the nested structure
    """
    result = {}
    
    # Process top-level specifications if present
    if 'top' in json_data and isinstance(json_data['top'], list):
        for item in json_data['top']:
            if isinstance(item, dict) and 'key' in item and 'value' in item:
                clean_key = item['key'].lower().replace(' ', '_').replace('(', '').replace(')', '')
                result[f'specs_top_{clean_key}'] = item['value']
    
    # Process detailed specifications in the data section
    if 'data' in json_data and isinstance(json_data['data'], list):
        for category in json_data['data']:
            if isinstance(category, dict) and 'heading' in category and 'list' in category:
                # Clean the category name
                category_name = category['heading'].lower().replace(' & ', '_').replace(' ', '_')
                
                # Process the specifications list
                if isinstance(category['list'], list):
                    # Store each specification as an individual column
                    for item in category['list']:
                        if isinstance(item, dict) and 'key' in item and 'value' in item:
                            clean_key = item['key'].lower().replace(' ', '_').replace('(', '').replace(')', '')
                            result[f'specs_{category_name}_{clean_key}'] = item['value']
                    
                    # Also store the complete JSON for the category
                    result[f'specs_{category_name}_json'] = json.dumps(category['list'])
    
    return result

def process_excel_files(file_paths: List[str], output_csv: str) -> pd.DataFrame:
    """
    Process Excel files containing car data with location verification
    """
    all_data = []
    
    for file_path in file_paths:
        # Extract city name from file path
        city_name = Path(file_path).stem.split('_')[0].capitalize()
        print(f"\nProcessing {city_name} data from {file_path}...")
        
        try:
            # Read Excel file
            df = pd.read_excel(file_path)
            print(f"Initial data shape for {city_name}: {df.shape}")
            
            # Add city column if not present
            if 'city' not in df.columns:
                df['city'] = city_name
            
            # Process each row
            for idx, row in df.iterrows():
                processed_row = {
                    'file_name': Path(file_path).name,
                    'row_index': idx,
                    'source_city': city_name  # Add explicit source city tracking
                }
                
                try:
                    # Store location information
                    processed_row['city'] = row.get('city', city_name)
                    if 'location' in row:
                        processed_row['location'] = row['location']
                    
                    # Process specs data
                    if 'new_car_specs' in row and pd.notna(row['new_car_specs']):
                        specs_data = row['new_car_specs']
                        if isinstance(specs_data, str):
                            try:
                                specs_dict = json.loads(specs_data)
                            except json.JSONDecodeError:
                                try:
                                    specs_dict = ast.literal_eval(specs_data)
                                except:
                                    print(f"Error parsing new_car_specs in row {idx}")
                                    specs_dict = {}
                        else:
                            specs_dict = specs_data
                            
                        if specs_dict:
                            specs_result = extract_car_specs(specs_dict)
                            processed_row.update(specs_result)
                    
                    # Process other JSON columns
                    if 'new_car_detail' in row:
                        json_data = parse_json_safely(row['new_car_detail'])
                        processed_row.update(extract_car_details(json_data))
                    
                    if 'new_car_overview' in row:
                        json_data = parse_json_safely(row['new_car_overview'])
                        processed_row.update(extract_car_overview(json_data))
                    
                    if 'new_car_feature' in row:
                        json_data = parse_json_safely(row['new_car_feature'])
                        processed_row.update(extract_car_features(json_data))
                    
                    # Add any non-JSON columns
                    for col in df.columns:
                        if col not in ['new_car_detail', 'new_car_overview', 'new_car_feature', 'new_car_specs']:
                            processed_row[col] = row[col]
                    
                except Exception as e:
                    print(f"Error processing row {idx} in {city_name} data: {str(e)}")
                    continue
                
                all_data.append(processed_row)
                
        except Exception as e:
            print(f"Error processing file {file_path}: {str(e)}")
            continue
    
    # Create final DataFrame
    final_df = pd.DataFrame(all_data)
    
    # Verify data by city
    print("\nData verification by city:")
    print(final_df['source_city'].value_counts())
    
    # Save to CSV
    if output_csv:
        final_df.to_csv(output_csv, index=False)
        print(f"\nSaved processed data to {output_csv}")
        
        # Print column summary by city
        print("\nColumn Summary by City:")
        for city in final_df['source_city'].unique():
            city_df = final_df[final_df['source_city'] == city]
            print(f"\n{city} Data Summary:")
            print(f"Total rows: {len(city_df)}")
            
            categories = ['detail_', 'overview_', 'feature_', 'specs_']
            for prefix in categories:
                cols = [col for col in city_df.columns if col.startswith(prefix)]
                if cols:
                    print(f"\n{prefix.upper()} columns in {city}:")
                    for col in sorted(cols):
                        non_null_count = city_df[col].notna().sum()
                        print(f"- {col} ({non_null_count} non-null values)")
    
    return final_df

def main():
    """
    Main function to execute the processing for multiple cities
    """
    excel_files = [
        r"C:\Users\Shiva\OneDrive\Desktop\cardekho\Dataset-20241106T053909Z-001\Dataset\jaipur_cars.xlsx"
    ]
    output_path = "processed_car_data_jaipur.csv"
    
    try:
        # Process files
        result_df = process_excel_files(excel_files, output_path)
        
        # Display statistics by city
        for city in result_df['source_city'].unique():
            city_df = result_df[result_df['source_city'] == city]
            print(f"\nStatistics for {city}:")
            print(f"Total cars: {len(city_df)}")
            
            if 'detail_price' in city_df.columns:
                print(f"\nPrice Distribution in {city}:")
                print(city_df['detail_price'].value_counts().head())
            
            if 'detail_modelYear' in city_df.columns:
                print(f"\nModel Year Distribution in {city}:")
                print(city_df['detail_modelYear'].value_counts().sort_index().head())
            
            if 'detail_transmission' in city_df.columns:
                print(f"\nTransmission Types in {city}:")
                print(city_df['detail_transmission'].value_counts())
            
            print("\n" + "="*50)
        
        # Save separate CSV files for each city
        for city in result_df['source_city'].unique():
            city_df = result_df[result_df['source_city'] == city]
            city_output = f"processed_car_data_{city.lower()}.csv"
            city_df.to_csv(city_output, index=False)
            print(f"\nSaved {city} data to {city_output}")
            
    except Exception as e:
        print(f"Error in main execution: {str(e)}")

if __name__ == "__main__":
    main()
# Out:
# Processing Jaipur data from C:\Users\Shiva\OneDrive\Desktop\cardekho\Dataset-20241106T053909Z-001\Dataset\jaipur_cars.xlsx...
# Initial data shape for Jaipur: (1120, 5)
#
# Data verification by city:
# source_city
# Jaipur    1120
# Name: count, dtype: int64
#
# Saved processed data to processed_car_data_jaipur.csv
#
# Column Summary by City:
#
# Jaipur Data Summary:
# Total rows: 1120
#
# DETAIL_ columns in Jaipur:
# - detail_bt (1120 non-null values)
# - detail_centralVariantId (1120 non-null values)
# - detail_ft (1120 non-null values)
# - detail_km (1120 non-null values)
# - detail_model (1120 non-null values)
# - detail_modelYear (1120 non-null values)
# - detail_oem (1120 non-null values)
# - detail_owner (1120 non-null values)
# - detail_ownerNo (1120 non-null values)
# - detail_price (1120 non-null values)
# - detail_priceFixedText (0 non-null values)
# - detail_transmission (1120 non-null values)
# - detail_trendingText (1120 non-null values)
# - detail_variantName (1120 non-null values)
#
# OVERVIEW_ columns in Jaipur:
# - overview_engine_displacement (1120 non-null values)
# - overview_fuel_type (1120 non-null values)
# - overview_insurance_validity (1120 non-null values)
# - overview_kms_driven (1119 non-null values)
# - overview_ownership (1119 non-null values)
# - overview_registration_year (1113 non-null values)
# - overview_rto (950 non-null values)
# - overview_seats (1119 non-null values)
# - overview_transmission (1120 non-null values)
# - overview_year_of_manufacture (1114 non-null values)
#
# FEATURE_ columns in Jaipur:
# - feature_comfort_convenience (1113 non-null values)
# - feature_entertainment_communication (919 non-null values)
# - feature_exterior (1107 non-null values)
# - feature_interior (1109 non-null values)
# - feature_safety (1105 non-null values)
# - feature_top (1120 non-null values)
#
# SPECS_ columns in Jaipur:
# - specs_dimensions_capacity_front_tread (622 non-null values)
# - specs_dimensions_capacity_gross_weight (539 non-null values)
# - specs_dimensions_capacity_ground_clearance_unladen (59 non-null values)
# - specs_dimensions_capacity_height (1107 non-null values)
# - specs_dimensions_capacity_json (1109 non-null values)
# - specs_dimensions_capacity_kerb_weight (1108 non-null values)
# - specs_dimensions_capacity_length (1107 non-null values)
# - specs_dimensions_capacity_rear_tread (622 non-null values)
# - specs_dimensions_capacity_wheel_base (1091 non-null values)
# - specs_dimensions_capacity_width (1107 non-null values)
# - specs_engine_and_transmission_borex_stroke (364 non-null values)
# - specs_engine_and_transmission_color (1120 non-null values)
# - specs_engine_and_transmission_compression_ratio (275 non-null values)
# - specs_engine_and_transmission_displacement (1120 non-null values)
# - specs_engine_and_transmission_engine_type (1079 non-null values)
# - specs_engine_and_transmission_fuel_suppy_system (912 non-null values)
# - specs_engine_and_transmission_json (1120 non-null values)
# - specs_engine_and_transmission_max_power (1111 non-null values)
# - specs_engine_and_transmission_max_torque (1111 non-null values)
# - specs_engine_and_transmission_no_of_cylinder (1113 non-null values)
# - specs_engine_and_transmission_super_charger (880 non-null values)
# - specs_engine_and_transmission_turbo_charger (995 non-null values)
# - specs_engine_and_transmission_value_configuration (815 non-null values)
# - specs_engine_and_transmission_values_per_cylinder (1113 non-null values)
# - specs_miscellaneous_acceleration (671 non-null values)
# - specs_miscellaneous_alloy_wheel_size (691 non-null values)
# - specs_miscellaneous_cargo_volumn (875 non-null values)
# - specs_miscellaneous_drive_type (908 non-null values)
# - specs_miscellaneous_front_brake_type (1108 non-null values)
# - specs_miscellaneous_gear_box (1103 non-null values)
# - specs_miscellaneous_json (1119 non-null values)
# - specs_miscellaneous_no_door_numbers (1117 non-null values)
# - specs_miscellaneous_rear_brake_type (1108 non-null values)
# - specs_miscellaneous_seating_capacity (1119 non-null values)
# - specs_miscellaneous_steering_type (1089 non-null values)
# - specs_miscellaneous_top_speed (633 non-null values)
# - specs_miscellaneous_turning_radius (921 non-null values)
# - specs_miscellaneous_tyre_type (1112 non-null values)
# - specs_top_engine (1120 non-null values)
# - specs_top_max_power (1111 non-null values)
# - specs_top_mileage (1092 non-null values)
# - specs_top_seats (1119 non-null values)
# - specs_top_torque (1111 non-null values)
# - specs_top_wheel_size (691 non-null values)
#
# Statistics for Jaipur:
# Total cars: 1120
#
# Price Distribution in Jaipur:
# detail_price
# ₹ 5 Lakh       33
# ₹ 4.50 Lakh    30
# ₹ 3 Lakh       29
# ₹ 3.50 Lakh    28
# ₹ 1.50 Lakh    26
# Name: count, dtype: int64
#
# Model Year Distribution in Jaipur:
# detail_modelYear
# 1998    1
# 1999    2
# 2001    3
# 2002    1
# 2003    1
# Name: count, dtype: int64
#
# Transmission Types in Jaipur:
# detail_transmission
# Manual       928
# Automatic    192
# Name: count, dtype: int64
#
# ==================================================
#
# Saved Jaipur data to processed_car_data_jaipur.csv

# %%
df_jaipur=pd.read_csv("processed_car_data_jaipur.csv")
df_jaipur
# Out:
#              file_name  row_index source_city    city specs_top_mileage  \
# 0     jaipur_cars.xlsx          0      Jaipur  Jaipur        22.54 kmpl
# 1     jaipur_cars.xlsx          1      Jaipur  Jaipur        22.38 kmpl
# 2     jaipur_cars.xlsx          2      Jaipur  Jaipur         23.1 kmpl
# 3     jaipur_cars.xlsx          3      Jaipur  Jaipur         18.9 kmpl
# 4     jaipur_cars.xlsx          4      Jaipur  Jaipur        20.51 kmpl
# ...                ...        ...         ...     ...               ...
# 1115  jaipur_cars.xlsx       1115      Jaipur  Jaipur         18.6 kmpl
# 1116  jaipur_cars.xlsx       1116      Jaipur  Jaipur         19.7 kmpl
# 1117  jaipur_cars.xlsx       1117      Jaipur  Jaipur        19.17 kmpl
# 1118  jaipur_cars.xlsx       1118      Jaipur  Jaipur         19.7 kmpl
# 1119  jaipur_cars.xlsx       1119      Jaipur  Jaipur         21.4 kmpl
#
#      specs_top_engine specs_top_max_power specs_top_torque  \
# 0             1396 CC            88.73bhp          219.7Nm
# 1             1197 CC            88.50bhp            113Nm
# 2              998 CC            67.04bhp             90Nm
# 3             1197 CC            81.86bhp         113.75nm
# 4              998 CC               67bhp             90Nm
# ...               ...                 ...              ...
# 1115          1199 CC             79.4bhp            108Nm
# 1116           796 CC             46.3bhp             62Nm
# 1117           999 CC            71.01bhp             96Nm
# 1118           796 CC             46.3bhp             62Nm
# 1119          1197 CC             83.1bhp            115Nm
#
#      specs_top_wheel_size  specs_top_seats  ...  \
# 0                      16              5.0  ...
# 1                     NaN              5.0  ...
# 2                     NaN              5.0  ...
# 3                     NaN              5.0  ...
# 4                     NaN              5.0  ...
# ...                   ...              ...  ...
# 1115                   14              5.0  ...
# 1116                   12              5.0  ...
# 1117                   16              5.0  ...
# 1118                   12              5.0  ...
# 1119                  NaN              5.0  ...
#
#                             feature_comfort_convenience  \
# 0     Power Steering, Power Windows Front, Power Win...
# 1     Power Steering, Power Windows Front, Power Win...
# 2     Power Steering, Power Windows Front, Power Win...
# 3     Power Steering, Power Windows Front, Power Win...
# 4     Power Steering, Power Windows Front, Power Win...
# ...                                                 ...
# 1115  Power Steering, Power Windows Front, Power Win...
# 1116                             Low Fuel Warning Light
# 1117  Power Steering, Power Windows Front, Power Win...
# 1118                             Low Fuel Warning Light
# 1119  Power Steering, Power Windows Front, Power Win...
#
#                                        feature_interior  \
# 0     Air Conditioner, Heater, Adjustable Steering, ...
# 1     Air Conditioner, Heater, Adjustable Steering, ...
# 2     Air Conditioner, Heater, Digital Odometer, Tac...
# 3     Air Conditioner, Heater, Digital Odometer, Tac...
# 4     Air Conditioner, Heater, Adjustable Steering, ...
# ...                                                 ...
# 1115  Air Conditioner, Heater, Adjustable Steering, ...
# 1116      Electronic Multi Tripmeter, Glove Compartment
# 1117  Air Conditioner, Heater, Adjustable Steering, ...
# 1118      Electronic Multi Tripmeter, Glove Compartment
# 1119  Air Conditioner, Heater, Adjustable Steering, ...
#
#                                        feature_exterior  \
# 0     Adjustable Head Lights, Fog Lights Front, Powe...
# 1     Adjustable Head Lights, Power Adjustable Exter...
# 2     Adjustable Head Lights, Manually Adjustable Ex...
# 3     Adjustable Head Lights, Power Adjustable Exter...
# 4     Adjustable Head Lights, Fog Lights Front, Powe...
# ...                                                 ...
# 1115  Fog Lights Front, Manually Adjustable Exterior...
# 1116      Manually Adjustable Exterior Rear View Mirror
# 1117  Adjustable Head Lights, Power Adjustable Exter...
# 1118      Manually Adjustable Exterior Rear View Mirror
# 1119  Adjustable Head Lights, Power Adjustable Exter...
#
#                                          feature_safety  \
# 0     Anti Lock Braking System, Centeral Locking, Po...
# 1     Anti Lock Braking System, Brake Assist, Center...
# 2     Centeral Locking, Child Safety Locks, Day Nigh...
# 3     Anti Lock Braking System, Centeral Locking, Po...
# 4     Centeral Locking, Power Door Locks, Child Safe...
# ...                                                 ...
# 1115  Centeral Locking, Day Night Rear View Mirror, ...
# 1116  Brake Assist, Halogen Headlamps, Rear Seat Bel...
# 1117  Anti Lock Braking System, Centeral Locking, Po...
# 1118  Brake Assist, Halogen Headlamps, Rear Seat Bel...
# 1119  Anti Lock Braking System, Centeral Locking, Po...
#
#                     feature_entertainment_communication  \
# 0     Cd Player, Radio, Speakers Front, Speakers Rea...
# 1     Radio, Speakers Front, Speakers Rear, Usb Auxi...
# 2                                                   NaN
# 3     Speakers Front, Speakers Rear, Integrated2Din ...
# 4     Cd Player, Radio, Speakers Front, Speakers Rea...
# ...                                                 ...
# 1115    Cd Player, Radio, Speakers Front, Speakers Rear
# 1116                                                NaN
# 1117  Radio, Speakers Front, Speakers Rear, Integrat...
# 1118                     Usb Auxiliary Input, Bluetooth
# 1119  Cd Player, Radio, Speakers Front, Speakers Rea...
#
#                                               car_links  \
# 0     https://www.cardekho.com/used-car-details/used...
# 1     https://www.cardekho.com/buy-used-car-details/...
# 2     https://www.cardekho.com/used-car-details/used...
# 3     https://www.cardekho.com/buy-used-car-details/...
# 4     https://www.cardekho.com/used-car-details/used...
# ...                                                 ...
# 1115  https://www.cardekho.com/used-car-details/used...
# 1116  https://www.cardekho.com/used-car-details/used...
# 1117  https://www.cardekho.com/used-car-details/used...
# 1118  https://www.cardekho.com/used-car-details/used...
# 1119  https://www.cardekho.com/used-car-details/used...
#
#       specs_dimensions_capacity_gross_weight  \
# 0                                        NaN
# 1                                       1335
# 2                                     1250kg
# 3                                        NaN
# 4                                     1350kg
# ...                                      ...
# 1115                                     NaN
# 1116                                  1140kg
# 1117                                     NaN
# 1118                                  1140kg
# 1119                                  1340kg
#
#      specs_engine_and_transmission_borex_stroke  \
# 0                                           NaN
# 1                                           NaN
# 2                                    73 X 82 mm
# 3                                           NaN
# 4                                    69 x 72 mm
# ...                                         ...
# 1115                                        NaN
# 1116                             68.5 x 72.0 mm
# 1117                                        NaN
# 1118                             68.5 x 72.0 mm
# 1119                                        NaN
#
#      specs_engine_and_transmission_compression_ratio  \
# 0                                                NaN
# 1                                                NaN
# 2                                             11.0:1
# 3                                                NaN
# 4                                                NaN
# ...                                              ...
# 1115                                             NaN
# 1116                                             NaN
# 1117                                             NaN
# 1118                                             NaN
# 1119                                             NaN
#
#      specs_dimensions_capacity_ground_clearance_unladen
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1115                                                NaN
# 1116                                                NaN
# 1117                                                NaN
# 1118                                                NaN
# 1119                                                NaN
#
# [1120 rows x 79 columns]

# %%
# Specify the full path with the filename, not just the directory
output_path = r"C:\Users\Shiva\OneDrive\Desktop\cardekho\Dataset-20241106T053909Z-001\Dataset\processed_car_data_jaipur.csv"

# Save the DataFrame to the specified path
df_jaipur.to_csv(output_path, index=False)

print(f"CSV file has been exported to '{output_path}'")
# Out:
# CSV file has been exported to 'C:\Users\Shiva\OneDrive\Desktop\cardekho\Dataset-20241106T053909Z-001\Dataset\processed_car_data_jaipur.csv'

# %%
def parse_json_safely(text: str) -> Dict:
    """
    Safely parse JSON string with multiple fallback methods
    """
    if not isinstance(text, str):
        return {}
    
    text = text.strip()
    if not text:
        return {}
        
    try:
        return json.loads(text)
    except json.JSONDecodeError:
        try:
            return ast.literal_eval(text)
        except:
            return {}

def extract_car_details(json_data: Dict) -> Dict[str, Any]:
    """
    Extract information from new_car_detail section
    """
    result = {}
    
    # Direct fields we want to extract
    fields = ['ft', 'bt', 'km', 'transmission', 'ownerNo', 'owner', 
              'oem', 'model', 'modelYear','centralVariantId', 'variantName', 'price', 'priceFixedText', 'trendingText']
    
    for field in fields:
        if field in json_data:
            result[f'detail_{field}'] = json_data[field]
    
    return result

def extract_car_overview(json_data: Dict) -> Dict[str, Any]:
    """
    Extract information from new_car_overview section
    """
    result = {}
    
    if 'top' in json_data and isinstance(json_data['top'], list):
        for item in json_data['top']:
            if isinstance(item, dict) and 'key' in item and 'value' in item:
                key = item['key'].lower().replace(' ', '_').replace('(', '').replace(')', '')
                result[f'overview_{key}'] = item['value']
    
    return result

def extract_car_features(json_data: Dict) -> Dict[str, Any]:
    """
    Extract information from new_car_feature section
    """
    result = {}
    
    # Extract top features
    if 'top' in json_data and isinstance(json_data['top'], list):
        top_features = [item.get('value', '') for item in json_data['top'] if isinstance(item, dict)]
        result['feature_top'] = ', '.join(filter(None, top_features))
    
    # Extract detailed features by category
    if 'data' in json_data and isinstance(json_data['data'], list):
        for category in json_data['data']:
            if isinstance(category, dict) and 'heading' in category and 'list' in category:
                category_name = category['heading'].lower().replace(' & ', '_').replace(' ', '_')
                features = [item.get('value', '') for item in category['list'] if isinstance(item, dict)]
                result[f'feature_{category_name}'] = ', '.join(filter(None, features))
    
    return result

def extract_car_specs(json_data: Dict) -> Dict[str, Any]:
    """
    Extract information from new_car_specs section with proper handling of the nested structure
    """
    result = {}
    
    # Process top-level specifications if present
    if 'top' in json_data and isinstance(json_data['top'], list):
        for item in json_data['top']:
            if isinstance(item, dict) and 'key' in item and 'value' in item:
                clean_key = item['key'].lower().replace(' ', '_').replace('(', '').replace(')', '')
                result[f'specs_top_{clean_key}'] = item['value']
    
    # Process detailed specifications in the data section
    if 'data' in json_data and isinstance(json_data['data'], list):
        for category in json_data['data']:
            if isinstance(category, dict) and 'heading' in category and 'list' in category:
                # Clean the category name
                category_name = category['heading'].lower().replace(' & ', '_').replace(' ', '_')
                
                # Process the specifications list
                if isinstance(category['list'], list):
                    # Store each specification as an individual column
                    for item in category['list']:
                        if isinstance(item, dict) and 'key' in item and 'value' in item:
                            clean_key = item['key'].lower().replace(' ', '_').replace('(', '').replace(')', '')
                            result[f'specs_{category_name}_{clean_key}'] = item['value']
                    
                    # Also store the complete JSON for the category
                    result[f'specs_{category_name}_json'] = json.dumps(category['list'])
    
    return result

def process_excel_files(file_paths: List[str], output_csv: str) -> pd.DataFrame:
    """
    Process Excel files containing car data with location verification
    """
    all_data = []
    
    for file_path in file_paths:
        # Extract city name from file path
        city_name = Path(file_path).stem.split('_')[0].capitalize()
        print(f"\nProcessing {city_name} data from {file_path}...")
        
        try:
            # Read Excel file
            df = pd.read_excel(file_path)
            print(f"Initial data shape for {city_name}: {df.shape}")
            
            # Add city column if not present
            if 'city' not in df.columns:
                df['city'] = city_name
            
            # Process each row
            for idx, row in df.iterrows():
                processed_row = {
                    'file_name': Path(file_path).name,
                    'row_index': idx,
                    'source_city': city_name  # Add explicit source city tracking
                }
                
                try:
                    # Store location information
                    processed_row['city'] = row.get('city', city_name)
                    if 'location' in row:
                        processed_row['location'] = row['location']
                    
                    # Process specs data
                    if 'new_car_specs' in row and pd.notna(row['new_car_specs']):
                        specs_data = row['new_car_specs']
                        if isinstance(specs_data, str):
                            try:
                                specs_dict = json.loads(specs_data)
                            except json.JSONDecodeError:
                                try:
                                    specs_dict = ast.literal_eval(specs_data)
                                except:
                                    print(f"Error parsing new_car_specs in row {idx}")
                                    specs_dict = {}
                        else:
                            specs_dict = specs_data
                            
                        if specs_dict:
                            specs_result = extract_car_specs(specs_dict)
                            processed_row.update(specs_result)
                    
                    # Process other JSON columns
                    if 'new_car_detail' in row:
                        json_data = parse_json_safely(row['new_car_detail'])
                        processed_row.update(extract_car_details(json_data))
                    
                    if 'new_car_overview' in row:
                        json_data = parse_json_safely(row['new_car_overview'])
                        processed_row.update(extract_car_overview(json_data))
                    
                    if 'new_car_feature' in row:
                        json_data = parse_json_safely(row['new_car_feature'])
                        processed_row.update(extract_car_features(json_data))
                    
                    # Add any non-JSON columns
                    for col in df.columns:
                        if col not in ['new_car_detail', 'new_car_overview', 'new_car_feature', 'new_car_specs']:
                            processed_row[col] = row[col]
                    
                except Exception as e:
                    print(f"Error processing row {idx} in {city_name} data: {str(e)}")
                    continue
                
                all_data.append(processed_row)
                
        except Exception as e:
            print(f"Error processing file {file_path}: {str(e)}")
            continue
    
    # Create final DataFrame
    final_df = pd.DataFrame(all_data)
    
    # Verify data by city
    print("\nData verification by city:")
    print(final_df['source_city'].value_counts())
    
    # Save to CSV
    if output_csv:
        final_df.to_csv(output_csv, index=False)
        print(f"\nSaved processed data to {output_csv}")
        
        # Print column summary by city
        print("\nColumn Summary by City:")
        for city in final_df['source_city'].unique():
            city_df = final_df[final_df['source_city'] == city]
            print(f"\n{city} Data Summary:")
            print(f"Total rows: {len(city_df)}")
            
            categories = ['detail_', 'overview_', 'feature_', 'specs_']
            for prefix in categories:
                cols = [col for col in city_df.columns if col.startswith(prefix)]
                if cols:
                    print(f"\n{prefix.upper()} columns in {city}:")
                    for col in sorted(cols):
                        non_null_count = city_df[col].notna().sum()
                        print(f"- {col} ({non_null_count} non-null values)")
    
    return final_df

def main():
    """
    Main function to execute the processing for multiple cities
    """
    excel_files = [
        r"C:\Users\Shiva\OneDrive\Desktop\cardekho\Dataset-20241106T053909Z-001\Dataset\kolkata_cars.xlsx"
    ]
    output_path = "processed_car_data_kolkata.csv"
    
    try:
        # Process files
        result_df = process_excel_files(excel_files, output_path)
        
        # Display statistics by city
        for city in result_df['source_city'].unique():
            city_df = result_df[result_df['source_city'] == city]
            print(f"\nStatistics for {city}:")
            print(f"Total cars: {len(city_df)}")
            
            if 'detail_price' in city_df.columns:
                print(f"\nPrice Distribution in {city}:")
                print(city_df['detail_price'].value_counts().head())
            
            if 'detail_modelYear' in city_df.columns:
                print(f"\nModel Year Distribution in {city}:")
                print(city_df['detail_modelYear'].value_counts().sort_index().head())
            
            if 'detail_transmission' in city_df.columns:
                print(f"\nTransmission Types in {city}:")
                print(city_df['detail_transmission'].value_counts())
            
            print("\n" + "="*50)
        
        # Save separate CSV files for each city
        for city in result_df['source_city'].unique():
            city_df = result_df[result_df['source_city'] == city]
            city_output = f"processed_car_data_{city.lower()}.csv"
            city_df.to_csv(city_output, index=False)
            print(f"\nSaved {city} data to {city_output}")
            
    except Exception as e:
        print(f"Error in main execution: {str(e)}")

if __name__ == "__main__":
    main()
# Out:
# Processing Kolkata data from C:\Users\Shiva\OneDrive\Desktop\cardekho\Dataset-20241106T053909Z-001\Dataset\kolkata_cars.xlsx...
# Initial data shape for Kolkata: (1381, 5)
#
# Data verification by city:
# source_city
# Kolkata    1381
# Name: count, dtype: int64
#
# Saved processed data to processed_car_data_kolkata.csv
#
# Column Summary by City:
#
# Kolkata Data Summary:
# Total rows: 1381
#
# DETAIL_ columns in Kolkata:
# - detail_bt (1381 non-null values)
# - detail_centralVariantId (1381 non-null values)
# - detail_ft (1381 non-null values)
# - detail_km (1381 non-null values)
# - detail_model (1381 non-null values)
# - detail_modelYear (1381 non-null values)
# - detail_oem (1381 non-null values)
# - detail_owner (1381 non-null values)
# - detail_ownerNo (1381 non-null values)
# - detail_price (1381 non-null values)
# - detail_priceFixedText (0 non-null values)
# - detail_transmission (1381 non-null values)
# - detail_trendingText (1381 non-null values)
# - detail_variantName (1381 non-null values)
#
# OVERVIEW_ columns in Kolkata:
# - overview_engine_displacement (1381 non-null values)
# - overview_fuel_type (1381 non-null values)
# - overview_insurance_validity (1381 non-null values)
# - overview_kms_driven (1381 non-null values)
# - overview_ownership (1377 non-null values)
# - overview_registration_year (1376 non-null values)
# - overview_rto (1203 non-null values)
# - overview_seats (1378 non-null values)
# - overview_transmission (1381 non-null values)
# - overview_year_of_manufacture (1380 non-null values)
#
# FEATURE_ columns in Kolkata:
# - feature_comfort_convenience (1365 non-null values)
# - feature_entertainment_communication (1150 non-null values)
# - feature_exterior (1365 non-null values)
# - feature_interior (1367 non-null values)
# - feature_safety (1365 non-null values)
# - feature_top (1381 non-null values)
#
# SPECS_ columns in Kolkata:
# - specs_dimensions_capacity_front_tread (822 non-null values)
# - specs_dimensions_capacity_gross_weight (613 non-null values)
# - specs_dimensions_capacity_ground_clearance_unladen (89 non-null values)
# - specs_dimensions_capacity_height (1369 non-null values)
# - specs_dimensions_capacity_json (1377 non-null values)
# - specs_dimensions_capacity_kerb_weight (1376 non-null values)
# - specs_dimensions_capacity_length (1369 non-null values)
# - specs_dimensions_capacity_rear_tread (822 non-null values)
# - specs_dimensions_capacity_wheel_base (1361 non-null values)
# - specs_dimensions_capacity_width (1369 non-null values)
# - specs_engine_and_transmission_borex_stroke (380 non-null values)
# - specs_engine_and_transmission_color (1381 non-null values)
# - specs_engine_and_transmission_compression_ratio (319 non-null values)
# - specs_engine_and_transmission_displacement (1381 non-null values)
# - specs_engine_and_transmission_engine_type (1328 non-null values)
# - specs_engine_and_transmission_fuel_suppy_system (1088 non-null values)
# - specs_engine_and_transmission_json (1381 non-null values)
# - specs_engine_and_transmission_max_power (1371 non-null values)
# - specs_engine_and_transmission_max_torque (1371 non-null values)
# - specs_engine_and_transmission_no_of_cylinder (1375 non-null values)
# - specs_engine_and_transmission_super_charger (1043 non-null values)
# - specs_engine_and_transmission_turbo_charger (1204 non-null values)
# - specs_engine_and_transmission_value_configuration (1003 non-null values)
# - specs_engine_and_transmission_values_per_cylinder (1370 non-null values)
# - specs_miscellaneous_acceleration (795 non-null values)
# - specs_miscellaneous_alloy_wheel_size (837 non-null values)
# - specs_miscellaneous_cargo_volumn (1098 non-null values)
# - specs_miscellaneous_drive_type (1110 non-null values)
# - specs_miscellaneous_front_brake_type (1366 non-null values)
# - specs_miscellaneous_gear_box (1362 non-null values)
# - specs_miscellaneous_json (1378 non-null values)
# - specs_miscellaneous_no_door_numbers (1377 non-null values)
# - specs_miscellaneous_rear_brake_type (1366 non-null values)
# - specs_miscellaneous_seating_capacity (1378 non-null values)
# - specs_miscellaneous_steering_type (1323 non-null values)
# - specs_miscellaneous_top_speed (740 non-null values)
# - specs_miscellaneous_turning_radius (1105 non-null values)
# - specs_miscellaneous_tyre_type (1367 non-null values)
# - specs_top_engine (1381 non-null values)
# - specs_top_max_power (1371 non-null values)
# - specs_top_mileage (1334 non-null values)
# - specs_top_seats (1378 non-null values)
# - specs_top_torque (1371 non-null values)
# - specs_top_wheel_size (837 non-null values)
#
# Statistics for Kolkata:
# Total cars: 1381
#
# Price Distribution in Kolkata:
# detail_price
# ₹ 4.50 Lakh    21
# ₹ 5 Lakh       20
# ₹ 6.50 Lakh    19
# ₹ 3 Lakh       18
# ₹ 5.50 Lakh    17
# Name: count, dtype: int64
#
# Model Year Distribution in Kolkata:
# detail_modelYear
# 1985    1
# 2002    2
# 2003    2
# 2004    2
# 2005    3
# Name: count, dtype: int64
#
# Transmission Types in Kolkata:
# detail_transmission
# Manual       1068
# Automatic     313
# Name: count, dtype: int64
#
# ==================================================
#
# Saved Kolkata data to processed_car_data_kolkata.csv

# %%
df_kolkata=pd.read_csv("processed_car_data_kolkata.csv")
df_kolkata
# Out:
#               file_name  row_index source_city     city specs_top_mileage  \
# 0     kolkata_cars.xlsx          0     Kolkata  Kolkata        19.16 kmpl
# 1     kolkata_cars.xlsx          1     Kolkata  Kolkata         22.7 kmpl
# 2     kolkata_cars.xlsx          2     Kolkata  Kolkata        19.03 kmpl
# 3     kolkata_cars.xlsx          3     Kolkata  Kolkata           17 kmpl
# 4     kolkata_cars.xlsx          4     Kolkata  Kolkata        15.73 kmpl
# ...                 ...        ...         ...      ...               ...
# 1376  kolkata_cars.xlsx       1376     Kolkata  Kolkata        25.24 kmpl
# 1377  kolkata_cars.xlsx       1377     Kolkata  Kolkata        22.74 kmpl
# 1378  kolkata_cars.xlsx       1378     Kolkata  Kolkata        11.74 kmpl
# 1379  kolkata_cars.xlsx       1379     Kolkata  Kolkata         18.5 kmpl
# 1380  kolkata_cars.xlsx       1380     Kolkata  Kolkata        19.72 kmpl
#
#      specs_top_engine specs_top_max_power       specs_top_torque  \
# 0             2494 CC            158.2bhp                  213Nm
# 1              799 CC            53.64bhp                   72Nm
# 2              999 CC            71.01bhp                   96Nm
# 3             1197 CC   80 PS at 5200 rpm  11.4 kgm at 4,000 rpm
# 4             1968 CC           174.33bhp                  380Nm
# ...               ...                 ...                    ...
# 1376           998 CC            65.71bhp                   89Nm
# 1377           796 CC             47.3bhp                   69Nm
# 1378          1796 CC              186bhp                  285Nm
# 1379          1197 CC            85.80bhp                  114Nm
# 1380          1461 CC           108.45bhp                  245Nm
#
#      specs_top_wheel_size  specs_top_seats  ...  \
# 0                      17              5.0  ...
# 1                     NaN              5.0  ...
# 2                     NaN              5.0  ...
# 3                      14              5.0  ...
# 4                      16              5.0  ...
# ...                   ...              ...  ...
# 1376                  NaN              5.0  ...
# 1377                  NaN              5.0  ...
# 1378                   17              5.0  ...
# 1379                   14              5.0  ...
# 1380                   16              5.0  ...
#
#                                        feature_interior  \
# 0     Air Conditioner, Heater, Adjustable Steering, ...
# 1     Air Conditioner, Heater, Tachometer, Electroni...
# 2     Air Conditioner, Heater, Adjustable Steering, ...
# 3     Air Conditioner, Heater, Adjustable Steering, ...
# 4     Air Conditioner, Heater, Adjustable Steering, ...
# ...                                                 ...
# 1376  Air Conditioner, Heater, Adjustable Steering, ...
# 1377  Air Conditioner, Heater, Digital Odometer, Ele...
# 1378  Air Conditioner, Heater, Adjustable Steering, ...
# 1379  Air Conditioner, Heater, Adjustable Steering, ...
# 1380  Air Conditioner, Heater, Adjustable Steering, ...
#
#                                        feature_exterior  \
# 0     Adjustable Head Lights, Fog Lights Front, Fog ...
# 1     Adjustable Head Lights, Manually Adjustable Ex...
# 2     Adjustable Head Lights, Power Adjustable Exter...
# 3     Fog Lights Rear, Power Adjustable Exterior Rea...
# 4     Adjustable Head Lights, Fog Lights Front, Fog ...
# ...                                                 ...
# 1376  Adjustable Head Lights, Power Adjustable Exter...
# 1377  Adjustable Head Lights, Manually Adjustable Ex...
# 1378  Adjustable Head Lights, Fog Lights Front, Fog ...
# 1379  Adjustable Head Lights, Fog Lights Front, Fog ...
# 1380  Adjustable Head Lights, Fog Lights Front, Powe...
#
#                                          feature_safety  \
# 0     Anti Lock Braking System, Brake Assist, Center...
# 1     Anti Lock Braking System, Centeral Locking, Ch...
# 2     Anti Lock Braking System, Centeral Locking, Po...
# 3     Centeral Locking, Power Door Locks, Child Safe...
# 4     Anti Lock Braking System, Brake Assist, Center...
# ...                                                 ...
# 1376  Anti Lock Braking System, Centeral Locking, Po...
# 1377  Day Night Rear View Mirror, Passenger Side Rea...
# 1378  Anti Lock Braking System, Brake Assist, Center...
# 1379  Anti Lock Braking System, Centeral Locking, Po...
# 1380  Anti Lock Braking System, Brake Assist, Center...
#
#                     feature_entertainment_communication  \
# 0     Cd Player, Dvd Player, Radio, Speakers Front, ...
# 1     Radio, Speakers Front, Usb Auxiliary Input, Bl...
# 2     Radio, Speakers Front, Speakers Rear, Integrat...
# 3       Cd Player, Radio, Speakers Front, Speakers Rear
# 4     Cd Player, Radio, Audio System Remote Control,...
# ...                                                 ...
# 1376  Radio, Speakers Front, Speakers Rear, Integrat...
# 1377                                                NaN
# 1378  Cd Player, Cd Changer, Radio, Audio System Rem...
# 1379  Cd Player, Radio, Speakers Front, Speakers Rea...
# 1380  Cd Player, Radio, Speakers Front, Speakers Rea...
#
#                                               car_links  \
# 0     https://www.cardekho.com/used-car-details/used...
# 1     https://www.cardekho.com/buy-used-car-details/...
# 2     https://www.cardekho.com/used-car-details/used...
# 3     https://www.cardekho.com/buy-used-car-details/...
# 4     https://www.cardekho.com/used-car-details/used...
# ...                                                 ...
# 1376  https://www.cardekho.com/used-car-details/used...
# 1377  https://www.cardekho.com/used-car-details/used...
# 1378  https://www.cardekho.com/used-car-details/used...
# 1379  https://www.cardekho.com/used-car-details/used...
# 1380  https://www.cardekho.com/used-car-details/used...
#
#       specs_dimensions_capacity_ground_clearance_unladen  \
# 0                                                   NaN
# 1                                                 185mm
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1376                                                NaN
# 1377                                                NaN
# 1378                                                NaN
# 1379                                                NaN
# 1380                                                NaN
#
#       specs_miscellaneous_cargo_volumn  \
# 0                                  NaN
# 1                                  222
# 2                                  405
# 3                              295 Lit
# 4                           460-litres
# ...                                ...
# 1376                               313
# 1377                        177-litres
# 1378                        475-litres
# 1379                        236-liters
# 1380                        410-litres
#
#      specs_engine_and_transmission_compression_ratio  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                 :1
# 4                                                NaN
# ...                                              ...
# 1376                                             NaN
# 1377                                             NaN
# 1378                                           9.3:1
# 1379                                             NaN
# 1380                                             NaN
#
#      specs_miscellaneous_acceleration specs_miscellaneous_top_speed
# 0                                 NaN                           NaN
# 1                                 NaN                           NaN
# 2                                 NaN                           NaN
# 3                           12.96 Sec                           NaN
# 4                         8.2 Seconds                      212 Kmph
# ...                               ...                           ...
# 1376                              NaN                           NaN
# 1377                       19 Seconds                      140 kmph
# 1378                      8.8 Seconds                      230km/hr
# 1379                       15 Seconds                      156 Kmph
# 1380                    14.20 Seconds                      168 Kmph
#
# [1381 rows x 79 columns]

# %%
# Specify the full path with the filename, not just the directory
output_path = r"C:\Users\Shiva\OneDrive\Desktop\cardekho\Dataset-20241106T053909Z-001\Dataset\processed_car_data_kolkata.csv"

# Save the DataFrame to the specified path
df_kolkata.to_csv(output_path, index=False)

print(f"CSV file has been exported to '{output_path}'")
# Out:
# CSV file has been exported to 'C:\Users\Shiva\OneDrive\Desktop\cardekho\Dataset-20241106T053909Z-001\Dataset\processed_car_data_kolkata.csv'
